# %%
pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2026.1.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %% [markdown]
# I tried with data that were not normalized but the result were awful
# Data Normalization
# The data get normalize towards the mean and the standard deviation, that are here calculate with built in function, in the next block code some of the data are printed to see the results

# %%
#Import of all the data from the dataset.
from ucimlrepo import fetch_ucirepo
import numpy as np
import random
import pandas as pd

# fetch dataset
wine_quality = fetch_ucirepo(id=186)

# data (as pandas dataframes)
X = wine_quality.data.features
y_og = wine_quality.data.targets

# metadata
print(wine_quality.metadata)

# variable information
print(wine_quality.variables)

# Standardization of the data to have a uniform learning
for column in X.columns:
  mean = X[column].mean()
  std = X[column].std()
  if std != 0:
    X[column] = (X[column] - mean) / std
  else:
    X[column] = 0

#print(X.describe().round(3))
# Out:
# {'uci_id': 186, 'name': 'Wine Quality', 'repository_url': 'https://archive.ics.uci.edu/dataset/186/wine+quality', 'data_url': 'https://archive.ics.uci.edu/static/public/186/data.csv', 'abstract': 'Two datasets are included, related to red and white vinho verde wine samples, from the north of Portugal. The goal is to model wine quality based on physicochemical tests (see [Cortez et al., 2009], http://www3.dsi.uminho.pt/pcortez/wine/).', 'area': 'Business', 'tasks': ['Classification', 'Regression'], 'characteristics': ['Multivariate'], 'num_instances': 4898, 'num_features': 11, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['quality'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2009, 'last_updated': 'Wed Nov 15 2023', 'dataset_doi': '10.24432/C56S3T', 'creators': ['Paulo Cortez', 'A. Cerdeira', 'F. Almeida', 'T. Matos', 'J. Reis'], 'intro_paper': {'ID': 252, 'type': 'NATIVE', 'title': 'Modeling wine preferences by data mining from physicochemical properties', 'authors': 'P. Cortez, A. Cerdeira, Fernando Almeida, Telmo Matos, J. Reis', 'venue': 'Decision Support Systems', 'year': 2009, 'journal': None, 'DOI': None, 'URL': 'https://www.semanticscholar.org/paper/Modeling-wine-preferences-by-data-mining-from-Cortez-Cerdeira/bf15a0ccc14ac1deb5cea570c870389c16be019c', 'sha': None, 'corpus': None, 'arxiv': None, 'mag': None, 'acl': None, 'pmid': None, 'pmcid': None}, 'additional_info': {'summary': 'The two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine. For more details, consult: http://www.vinhoverde.pt/en/ or the reference [Cortez et al., 2009].  Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).\n\nThese datasets can be viewed as classification or regression tasks.  The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Outlier detection algorithms could be used to detect the few excellent or poor wines. Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.\n', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'For more information, read [Cortez et al., 2009].\r\nInput variables (based on physicochemical tests):\r\n   1 - fixed acidity\r\n   2 - volatile acidity\r\n   3 - citric acid\r\n   4 - residual sugar\r\n   5 - chlorides\r\n   6 - free sulfur dioxide\r\n   7 - total sulfur dioxide\r\n   8 - density\r\n   9 - pH\r\n   10 - sulphates\r\n   11 - alcohol\r\nOutput variable (based on sensory data): \r\n   12 - quality (score between 0 and 10)', 'citation': None}}
#                     name     role         type demographic  \
# 0          fixed_acidity  Feature   Continuous        None
# 1       volatile_acidity  Feature   Continuous        None
# 2            citric_acid  Feature   Continuous        None
# 3         residual_sugar  Feature   Continuous        None
# 4              chlorides  Feature   Continuous        None
# 5    free_sulfur_dioxide  Feature   Continuous        None
# 6   total_sulfur_dioxide  Feature   Continuous        None
# 7                density  Feature   Continuous        None
# 8                     pH  Feature   Continuous        None
# 9              sulphates  Feature   Continuous        None
# 10               alcohol  Feature   Continuous        None
# 11               quality   Target      Integer        None
# 12                 color    Other  Categorical        None
#
#                description units missing_values
# 0                     None  None             no
# 1                     None  None             no
# 2                     None  None             no
# 3                     None  None             no
# 4                     None  None             no
# 5                     None  None             no
# 6                     None  None             no
# 7                     None  None             no
# 8                     None  None             no
# 9                     None  None             no
# 10                    None  None             no
# 11  score between 0 and 10  None             no
# 12            red or white  None             no
# /tmp/ipython-input-266/107887002.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[column] = (X[column] - mean) / std

# %%
# View the first few rows of features
print(X.head())

# View the first few rows of targets
print(y_og.head())

# Or see both together
print(X.head(10))  # Shows first 10 rows
print(y_og.head(10))

# To see the shape (number of rows and columns)
print(X.shape)
print(y_og.shape)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0       0.142462          2.188664    -2.192664       -0.744721   0.569914
# 1       0.451001          3.281982    -2.192664       -0.597594   1.197883
# 2       0.451001          2.553104    -1.917405       -0.660648   1.026618
# 3       3.073580         -0.362411     1.660957       -0.744721   0.541370
# 4       0.142462          2.188664    -2.192664       -0.744721   0.569914
#
#    free_sulfur_dioxide  total_sulfur_dioxide   density        pH  sulphates  \
# 0            -1.100055             -1.446247  1.034913  1.812950   0.193082
# 1            -0.311296             -0.862402  0.701432 -0.115064   0.999502
# 2            -0.874695             -1.092402  0.768128  0.258100   0.797897
# 3            -0.762016             -0.986248  1.101609 -0.363840   0.327485
# 4            -1.100055             -1.446247  1.034913  1.812950   0.193082
#
#     alcohol
# 0 -0.915394
# 1 -0.580023
# 2 -0.580023
# 3 -0.580023
# 4 -0.915394
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0       0.142462          2.188664    -2.192664       -0.744721   0.569914
# 1       0.451001          3.281982    -2.192664       -0.597594   1.197883
# 2       0.451001          2.553104    -1.917405       -0.660648   1.026618
# 3       3.073580         -0.362411     1.660957       -0.744721   0.541370
# 4       0.142462          2.188664    -2.192664       -0.744721   0.569914
# 5       0.142462          1.945705    -2.192664       -0.765739   0.541370
# 6       0.528136          1.581266    -1.779776       -0.807775   0.370106
# 7       0.065328          1.884965    -2.192664       -0.891847   0.255930
# 8       0.451001          1.459786    -2.055034       -0.723703   0.484282
# 9       0.219597          0.973867     0.284664        0.138039   0.427194
#
#    free_sulfur_dioxide  total_sulfur_dioxide   density        pH  sulphates  \
# 0            -1.100055             -1.446247  1.034913  1.812950   0.193082
# 1            -0.311296             -0.862402  0.701432 -0.115064   0.999502
# 2            -0.874695             -1.092402  0.768128  0.258100   0.797897
# 3            -0.762016             -0.986248  1.101609 -0.363840   0.327485
# 4            -1.100055             -1.446247  1.034913  1.812950   0.193082
# 5            -0.987375             -1.340094  1.034913  1.812950   0.193082
# 6            -0.874695             -1.003940  0.568040  0.506876  -0.478935
# 7            -0.874695             -1.676247 -0.032226  1.066622  -0.411733
# 8            -1.212735             -1.729324  0.701432  0.880040   0.260284
# 9            -0.762016             -0.243173  1.034913  0.817846   1.805921
#
#     alcohol
# 0 -0.915394
# 1 -0.580023
# 2 -0.580023
# 3 -0.580023
# 4 -0.915394
# 5 -0.915394
# 6 -0.915394
# 7 -0.412338
# 8 -0.831551
# 9  0.006874
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5
# 5        5
# 6        5
# 7        7
# 8        7
# 9        5
# (6497, 11)
# (6497, 1)

# %%
print(f"dataset: {len(X)} row")

print(y_og.value_counts())
# Out:
# dataset: 6497 row
# quality
# 6          2836
# 5          2138
# 7          1079
# 4           216
# 8           193
# 3            30
# 9             5
# Name: count, dtype: int64

# %%
def convert_data(Y):
  Y_copy = Y.copy()
  Y_copy[Y_copy < 6] = -1
  Y_copy[Y_copy >= 6] = 1
  return Y_copy

# %%
y = convert_data(y_og)

# %% [markdown]
# DATA SPLIT
# Data are divided in train and test set respectively, then the output y, which represent the quality of wine, get converted in a binary format that can use to perform binary classification.

# %%
#Split data in training and test set, to get only train and ratio put eval_ratio = 0
def split_data(X, y, train_ratio, eval_ratio, test_ratio):
  #randomize my data
  indices = np.random.permutation(len(X))
  if hasattr(X, 'iloc'):
    X_shuffle = X.iloc[indices]
    y_shuffle = y.iloc[indices]
  else:
    X_shuffle = X[indices]
    y_shuffle = y[indices]

  #get length of every part
  train_part = int(len(X) * train_ratio)
  eval_part = int(train_part + len(X) * eval_ratio)
  #split dataset in different parts.
  X_train = X_shuffle[:train_part]
  y_train = y_shuffle[:train_part]
  X_eval = X_shuffle[train_part:eval_part]
  y_eval = y_shuffle[train_part:eval_part]
  X_test = X_shuffle[eval_part:]
  y_test = y_shuffle[eval_part:]
  return X_train, y_train, X_eval, y_eval, X_test, y_test

# %% [markdown]
# Model define both the SVM and the LR, when defining the class you can choose which class by using a string "SVM" if i want to use the SVM model, "LR" otherwise.

# %%
class Model:
  #First thing to do is initialize at random the weight matrix. The number of column is given by the len of X that we want to multiply
  def __init__(self, X, Y, model, X_val = None, Y_val = None):
    self.X = X
    self.Y = Y
    self.model = model
    self.w = np.random.rand(len(X.columns))
    self.b = 0
    self.loss = []
    self.acc = []
    self.epochs = []
    self.val_loss = []
    self.val_acc = []
    self.val_epochs = []


  def training(self, learning_rate, epochs, lam, X_val = None, Y_val = None):
    self.Y = self.Y.values
    #for n epoch i have to multiply w and x and calculate the error (distance from y)
    self.X = self.X.values

    if self.model == "SVM":
      for epoch in range(epochs):
        epoch_loss = 0
        epoch_acc = 0
        for i in range(len(self.X)):
          loss, acc = self.training_step_svm(i, learning_rate, lam)
          epoch_loss += loss
          epoch_acc += acc

        self.loss.append(epoch_loss/len(self.X))
        self.epochs.append(epoch)
        self.acc.append(epoch_acc/len(self.X))
        if X_val is not None and Y_val is not None:
            epoch_val_loss, epoch_val_acc = self.evaluate(X_val, Y_val)
            self.val_loss.append(epoch_val_loss)
            self.val_acc.append(epoch_val_acc)
            self.val_epochs.append(epoch)

        if epoch % 10 == 0:
          print("Epoch:", epoch)

    else:
      for epoch in range(epochs):
        epoch_loss = 0
        epoch_acc = 0
        for i in range(len(self.X)):
          loss, acc = self.training_step_lr(i, learning_rate, lam)
          epoch_loss += loss
          epoch_acc += acc

        self.loss.append(epoch_loss/len(self.X))
        self.epochs.append(epoch)
        #calculate accuracy
        self.acc.append(epoch_acc/len(self.X))
        if X_val is not None and Y_val is not None:
            epoch_val_loss, epoch_val_acc = self.evaluate(X_val, Y_val)
            self.val_loss.append(epoch_val_loss)
            self.val_acc.append(epoch_val_acc)
            self.val_epochs.append(epoch)

        if epoch % 10 == 0:
          print("Epoch:", epoch)


  def training_step_svm(self, i, learning_rate, lam):
    #get the values to calculation
    x = self.X[i]
    y = self.Y[i]

    #execute the multiplication
    condition = y * (np.dot(self.w, x) + self.b)
    loss = max(0, 1 - condition)
    regularization = lam * np.dot(self.w, self.w)
    total_loss = loss + regularization

    if condition > 0:
      acc = 1
    else:
      acc = 0

    #Hinge loss, if condition is right still push the values.
    if condition >= 1:
      #correct classification (concordance between y and w*x), i just use the regularization to keep w small
      self.w = self.w - learning_rate * (2 * lam * self.w)
    else:
      #update to shift the hyperplane
      self.w = self.w - learning_rate * (2 * lam * self.w - y*x)
      self.b = self.b + learning_rate * y

    #this are added to plot the loss and accuracies
    return total_loss, acc

  def training_step_lr(self, i, learning_rate, lam):
      x_i = self.X[i]
      y_i = self.Y[i]
      #Calculation of the probability of an event given his inputs
      z = np.dot(self.w, x_i) + self.b

      #Loss here is for plotting purpose after
      loss = np.log2(1 + np.exp(-y_i * z))
      regularization = (lam / 2) * np.dot(self.w, self.w) #last one is norm of w
      total_loss = loss + regularization

      if y_i * z > 0:
        acc = 1
      else:
        acc = 0

      #adjust weight and bias accordingly to gradient of loss
      prob = 1 / (1 + np.exp(-y_i * z))
      error = 1 - prob
      update = - (y_i * x_i) * error + lam * self.w
      self.w = self.w - learning_rate * update
      self.b = self.b + learning_rate * y_i * error
      return total_loss, acc


  #With new data we want to predict on a test set X
  def predict(self, X):
    predictions = []
    if self.model == "SVM":
      for i in range(len(X)):
          x = X.iloc[i].values
          prediction = np.sign(np.dot(self.w, x) + self.b)
          predictions.append(prediction)
    else:
      for i in range(len(X)):
        #probability
        z = np.dot(self.w, X.iloc[i].values) + self.b
        prediction = 1 / (1 + np.exp(-z))
        #convert the probability in a real output.
        if prediction >= 0.5:
          prediction = 1
        else:
          prediction = -1

        predictions.append(prediction)

    return np.array(predictions).ravel()


  def accuracy(self, X, Y):
    correct = 0
    total = 0
    if self.model == "SVM":
      for i in range(len(X)):
        prediction = np.sign(np.dot(self.w,X[i]) + self.b)
        if prediction == Y[i]:
          correct += 1
          total += 1
        else:
          total += 1
    else:
      for i in range(len(X)):
        z = np.dot(self.w,X[i]) + self.b
        #convert the prob into a prediction
        if z >= 0:
          prediction = 1
        else:
          prediction = -1
        #check the prediction
        if prediction == Y[i]:
          correct += 1
          total += 1
        else:
          total += 1

    #this is the correction rate through all the X
    return correct / total

  def evaluate(self, X_val, Y_val):
    X_val = X_val.values
    Y_val = Y_val.values
    val_loss = 0
    val_acc = 0

    for i in range(len(X_val)):
      x = X_val[i]
      y = Y_val[i]
      z = np.dot(self.w, x) + self.b

      if self.model == "SVM":
        val_loss += max(0, 1 - y * z)
        if y * z > 0:
          val_acc += 1
      else:
        exp_term = np.exp(np.clip(-y * z, -500, 500))
        val_loss += np.log2(1 + exp_term)
        if y * z > 0:
          val_acc += 1

    return val_loss/len(X_val), val_acc/len(X_val)

# %% [markdown]
# Performance metric

# %%
def accuracy(pred, Y):
    predictions = pred
    accuracy_score = np.mean(predictions == Y)
    return accuracy_score

def precision(pred, Y):
    predictions = pred
    true_positives = np.sum((predictions == 1) & (Y == 1))
    false_positives = np.sum((predictions == 1) & (Y == -1))
    precision_score = true_positives / (true_positives + false_positives)
    return precision_score

def recall(pred, Y):
    predictions = pred
    true_positives = np.sum((predictions == 1) & (Y == 1))
    false_negatives = np.sum((predictions == -1) & (Y == 1))
    recall_score = true_positives / (true_positives + false_negatives)
    return recall_score

def F1_score(pred, Y):
    prec = precision(pred, Y)
    rec = recall(pred, Y)
    f1_score = 2 * (prec * rec) / (prec + rec)
    return f1_score

def performance_metric(pred, Y):
  print("Accuracy:", accuracy(pred, Y))
  print("Precision:", precision(pred, Y))
  print("Recall:", recall(pred, Y))
  print("F1 score:", F1_score(pred, Y))
  return accuracy(pred, Y), precision(pred, Y), recall(pred, Y), F1_score(pred, Y)

# %% [markdown]
# Evaluation of the two models: using self made hyperparameter(not fine tuned, no cross-validation). A problem that occurred was that the recall in logistic regression was 1 due to a bad choice of the lambda parameter.

# %%
split_ratio = 0.7
eval_ratio = 0.15
test_ratio = 0.15
X_train, y_train, X_eval, y_eval, X_test, y_test = split_data(X, y, split_ratio, eval_ratio ,test_ratio)

model_svm = Model(X_train, y_train, "SVM", X_val = X_eval ,Y_val = y_eval)
model_lr = Model(X_train, y_train, "LR", X_val = X_eval ,Y_val = y_eval)

#Note that the best hyperparameter find with cross validation indicate to use both learning rate and lambda as 0.001. if wanted someone can run the svm
#code commented (but remember to comment the other training)

#model_svm.training(0.001, 50, 0.001, X_val = X_eval ,Y_val = y_eval)
model_svm.training(0.01, 50, 0.01, X_val = X_eval ,Y_val = y_eval)
model_lr.training(0.001, 50, 0.001, X_val = X_eval ,Y_val = y_eval)

pred_svm = model_svm.predict(X_test)
pred_lr = model_lr.predict(X_test)

y_test_flat = np.array(y_test).ravel()

print("SVM test:")
performance_metric(pred_svm, y_test_flat)
print("\n")
print("Logistic regression test:")
performance_metric(pred_lr, y_test_flat)
# Out:
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# SVM test:
# Accuracy: 0.7418032786885246
# Precision: 0.7472375690607734
# Recall: 0.8868852459016393
# F1 score: 0.8110944527736131
#
#
# Logistic regression test:
# Accuracy: 0.735655737704918
# Precision: 0.7666666666666667
# Recall: 0.8295081967213115
# F1 score: 0.7968503937007875
# (np.float64(0.735655737704918),
#  np.float64(0.7666666666666667),
#  np.float64(0.8295081967213115),
#  np.float64(0.7968503937007875))

# %% [markdown]
# Loss and Accuracy of the models

# %%
import matplotlib.pyplot as plt

plt.plot(model_svm.epochs, model_svm.loss, label = "Training Loss")

plt.plot(model_svm.val_epochs, model_svm.val_loss, label="Validation Loss", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.title('loss through time')
plt.show()

# %%
plt.plot(model_svm.epochs, model_svm.acc, label = "Training Accuracy")

plt.plot(model_svm.val_epochs, model_svm.val_acc, label="Validation Loss", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy through time')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(model_lr.epochs, model_lr.loss, label = "Training Loss")

plt.plot(model_lr.val_epochs, model_lr.val_loss, label="Validation Loss", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.title('loss through time')
plt.show()

# %%
plt.plot(model_lr.epochs, model_lr.acc, label = "Training Accuracy")

plt.plot(model_lr.val_epochs, model_lr.val_acc, label="Validation Loss", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy through time')
plt.show()

# %% [markdown]
# Cross Validation. The cross validation is implemented to try different model with a certain learning rate, epochs, lambda, and potentially even the kernelized function. A grid search is then used to try all the possible combination of learning rates, epochs and lambda to get the best results in a pool. Optionally also the kernelized version can be tested by adding the kernel.

# %%
#kernel params are the params that are needed to run the alghoritm
def cross_fold_validation(X, Y, k, model, learning_rate, epochs, lam):
  indices = np.random.permutation(len(X))
  X_shuffle = X.iloc[indices]
  Y_shuffle = Y.iloc[indices]

  #split train in k different folds
  X_folds = np.array_split(X_shuffle, k)
  Y_folds = np.array_split(Y_shuffle, k)

  folds_scores = []
  models = []

  #training
  for i in range(k):
    X_eval = X_folds[i]
    Y_eval = Y_folds[i]

    X_train_fold = pd.concat([x for j, x in enumerate(X_folds) if j != i]).reset_index(drop=True)
    Y_train_fold = pd.concat([y for j, y in enumerate(Y_folds) if j != i]).reset_index(drop=True)

    if model == "SVM":
      clf = Model(X_train_fold, Y_train_fold, "SVM")
      clf.training(learning_rate, epochs, lam)
      pred = clf.predict(X_eval)
    else:
      clf = Model(X_train_fold, Y_train_fold, "LR")
      clf.training(learning_rate, epochs, lam)
      pred = clf.predict(X_eval)

    acc, prec, rec, f1 = performance_metric(pred, Y_eval.values.ravel())
    folds_scores.append(acc)
    models.append(clf)

    print(f"Fold {i+1}: {acc}")

  avg_score = np.mean(folds_scores, axis=0)
  print("Average score is:", avg_score ,"for lam = ", lam, "and learning rate =", learning_rate, "with number of epochs:", epochs)
  return avg_score



def grid_search(X, Y, k, model, learning_rate_range, epochs_range, lam_range):
  best_score = 0
  best_lam = 0
  best_lr = 0
  best_epoch = 0
  for lam in lam_range:
    for lr in learning_rate_range:
      for epochs in epochs_range:
        #This time we had to classify wines, accuracy is the best parameter to check
        accuracy = cross_fold_validation(X, Y, k, model, lr, epochs, lam)
        if accuracy > best_score:
          best_score = accuracy
          best_lam = lam
          best_lr = lr
          best_epoch = epochs


  print("Best score is: ", best_score, "with lam = ", best_lam, "with lr = ", best_lr, "with epochs = ", best_epoch)
  return best_score, best_lam, best_lr, best_epoch

# %% [markdown]
# Because a cross fold need many minutes the SVM and the LR are done in separate blocks.

# %%
learning_rates = [0.01, 0.005, 0.001]
#epochs  can be tested also over 100 but it become much more expensive
epochs_range = [50, 100]
lam_range = [0.001, 0.01, 0.1]
model_svm = "SVM"
train_ratio = 0.8
k = 5

score, lam, lr, epoch = grid_search(X_train, y_train, k, model_svm, learning_rates, epochs_range, lam_range)

final_model_svm = Model(X_train, y_train, model_svm)
final_model_svm.training(lr, epoch, lam, X_val = X_eval, Y_val = y_eval)

print("valutazione sul testo")
pred = final_model_svm.predict(X_test)
final_acc, final_prec, final_rec, final_f1 = performance_metric(pred, y_test.values.ravel())
print("best learning rate: " ,lr, "best epoch: " ,epoch, "best lam: ", lam)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7428571428571429
# Precision: 0.8006872852233677
# Recall: 0.797945205479452
# F1 score: 0.7993138936535162
# Fold 1: 0.7428571428571429
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.721978021978022
# Precision: 0.7843803056027164
# Recall: 0.7857142857142857
# F1 score: 0.7850467289719626
# Fold 2: 0.721978021978022
# Epoch: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-266/357883347.py in <cell line: 0>()
#       7 k = 5
#       8
# ----> 9 score, lam, lr, epoch = grid_search(X_train, y_train, k, model_svm, learning_rates, epochs_range, lam_range)
#      10
#      11 final_model_svm = Model(X_train, y_train, model_svm)
#
# /tmp/ipython-input-266/1404430388.py in grid_search(X, Y, k, model, learning_rate_range, epochs_range, lam_range)
#      50       for epochs in epochs_range:
#      51         #This time we had to classify wines, accuracy is the best parameter to check
# ---> 52         accuracy = cross_fold_validation(X, Y, k, model, lr, epochs, lam)
#      53         if accuracy > best_score:
#      54           best_score = accuracy
#
# /tmp/ipython-input-266/1404430388.py in cross_fold_validation(X, Y, k, model, learning_rate, epochs, lam)
#      22     if model == "SVM":
#      23       clf = Model(X_train_fold, Y_train_fold, "SVM")
# ---> 24       clf.training(learning_rate, epochs, lam)
#      25       pred = clf.predict(X_eval)
#      26     else:
#
# /tmp/ipython-input-266/275183825.py in training(self, learning_rate, epochs, lam, X_val, Y_val)
#      25         epoch_acc = 0
#      26         for i in range(len(self.X)):
# ---> 27           loss, acc = self.training_step_svm(i, learning_rate, lam)
#      28           epoch_loss += loss
#      29           epoch_acc += acc
#
# /tmp/ipython-input-266/275183825.py in training_step_svm(self, i, learning_rate, lam)
#      70
#      71     #execute the multiplication
# ---> 72     condition = y * (np.dot(self.w, x) + self.b)
#      73     loss = max(0, 1 - condition)
#      74     regularization = lam * np.dot(self.w, self.w)
#
# KeyboardInterrupt:

# %%
learning_rates = [0.01, 0.005, 0.001]
epochs_range = [50, 100]
lam_range = [0.001, 0.01, 0.1]
model_lr = "LR"
train_ratio = 0.8
k = 5

#the data were splitted before in the block above this

score, lam, lr, epoch = grid_search(X_train, y_train, k, model_lr, learning_rates, epochs_range, lam_range)

final_model_lr = Model(X_train, y_train, model_lr)
final_model_lr.training(lr, epoch, lam, X_val = X_eval, Y_val = y_eval)
pred = final_model_lr.predict(X_test)
final_acc, final_prec, final_rec, final_f1 = performance_metric(pred, y_test.values.ravel())
print("best learning rate: " ,lr, "best epoch: " ,epoch, "best lam: ", lam)
# Out:
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7307692307692307
# Precision: 0.7622047244094489
# Recall: 0.8373702422145328
# F1 score: 0.7980214344600164
# Fold 1: 0.7307692307692307
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7373626373626374
# Precision: 0.7758620689655172
# Recall: 0.8375634517766497
# F1 score: 0.8055329536208298
# Fold 2: 0.7373626373626374
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7216721672167217
# Precision: 0.7296875
# Recall: 0.8537477148080439
# F1 score: 0.7868576242628474
# Fold 3: 0.7216721672167217
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7425742574257426
# Precision: 0.7652733118971061
# Recall: 0.8439716312056738
# F1 score: 0.8026981450252951
# Fold 4: 0.7425742574257426
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7546754675467546
# Precision: 0.7777777777777778
# Recall: 0.8690476190476191
# F1 score: 0.8208835341365462
# Fold 5: 0.7546754675467546
# Average score is: 0.7374107520642175 for lam =  0.001 and learning rate = 0.01 with number of epochs: 50
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7307692307692307
# Precision: 0.7616
# Recall: 0.8321678321678322
# F1 score: 0.7953216374269007
# Fold 1: 0.7307692307692307
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7494505494505495
# Precision: 0.7809983896940419
# Recall: 0.8405545927209706
# F1 score: 0.8096828046744575
# Fold 2: 0.7494505494505495
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7392739273927392
# Precision: 0.76875
# Recall: 0.846815834767642
# F1 score: 0.8058968058968059
# Fold 3: 0.7392739273927392
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7183718371837183
# Precision: 0.74481658692185
# Recall: 0.8294849023090586
# F1 score: 0.7848739495798319
# Fold 4: 0.7183718371837183
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.746974697469747
# Precision: 0.778675282714055
# Recall: 0.8382608695652174
# F1 score: 0.8073701842546064
# Fold 5: 0.746974697469747
# Average score is: 0.736968048453197 for lam =  0.001 and learning rate = 0.01 with number of epochs: 100
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7296703296703296
# Precision: 0.7857142857142857
# Recall: 0.8016949152542373
# F1 score: 0.7936241610738255
# Fold 1: 0.7296703296703296
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7274725274725274
# Precision: 0.766612641815235
# Recall: 0.8197573656845754
# F1 score: 0.7922948073701843
# Fold 2: 0.7274725274725274
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7414741474147415
# Precision: 0.7901861252115059
# Recall: 0.8079584775086506
# F1 score: 0.7989734816082121
# Fold 3: 0.7414741474147415
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7392739273927392
# Precision: 0.7728026533996684
# Recall: 0.823321554770318
# F1 score: 0.7972626176218991
# Fold 4: 0.7392739273927392
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.724972497249725
# Precision: 0.7545605306799337
# Recall: 0.8168761220825853
# F1 score: 0.7844827586206896
# Fold 5: 0.724972497249725
# Average score is: 0.7325726858400126 for lam =  0.001 and learning rate = 0.005 with number of epochs: 50
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7505494505494505
# Precision: 0.7678018575851393
# Recall: 0.8656195462478184
# F1 score: 0.8137817883511074
# Fold 1: 0.7505494505494505
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7153846153846154
# Precision: 0.7397881996974282
# Recall: 0.8489583333333334
# F1 score: 0.7906224737267583
# Fold 2: 0.7153846153846154
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7414741474147415
# Precision: 0.7569230769230769
# Recall: 0.8646748681898067
# F1 score: 0.8072190319934373
# Fold 3: 0.7414741474147415
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7183718371837183
# Precision: 0.7511591962905718
# Recall: 0.8364888123924269
# F1 score: 0.7915309446254072
# Fold 4: 0.7183718371837183
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7381738173817382
# Precision: 0.7656500802568218
# Recall: 0.8383128295254832
# F1 score: 0.8003355704697986
# Fold 5: 0.7381738173817382
# Average score is: 0.7327907735828527 for lam =  0.001 and learning rate = 0.005 with number of epochs: 100
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7494505494505495
# Precision: 0.780952380952381
# Recall: 0.845360824742268
# F1 score: 0.8118811881188118
# Fold 1: 0.7494505494505495
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7549450549450549
# Precision: 0.7865168539325843
# Recall: 0.8448275862068966
# F1 score: 0.8146300914380715
# Fold 2: 0.7549450549450549
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7337733773377337
# Precision: 0.7792642140468228
# Recall: 0.8090277777777778
# F1 score: 0.7938671209540035
# Fold 3: 0.7337733773377337
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7183718371837183
# Precision: 0.7515151515151515
# Recall: 0.8435374149659864
# F1 score: 0.7948717948717948
# Fold 4: 0.7183718371837183
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7128712871287128
# Precision: 0.7233704292527822
# Recall: 0.8394833948339483
# F1 score: 0.7771135781383434
# Fold 5: 0.7128712871287128
# Average score is: 0.7338824212091538 for lam =  0.001 and learning rate = 0.001 with number of epochs: 50
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7494505494505495
# Precision: 0.7677725118483413
# Recall: 0.8571428571428571
# F1 score: 0.81
# Fold 1: 0.7494505494505495
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7274725274725274
# Precision: 0.7535101404056163
# Recall: 0.8429319371727748
# F1 score: 0.7957166392092258
# Fold 2: 0.7274725274725274
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7414741474147415
# Precision: 0.7774193548387097
# Recall: 0.8324697754749568
# F1 score: 0.8040033361134279
# Fold 3: 0.7414741474147415
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7436743674367436
# Precision: 0.7847896440129449
# Recall: 0.8290598290598291
# F1 score: 0.8063175394846219
# Fold 4: 0.7436743674367436
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7018701870187019
# Precision: 0.7271317829457364
# Recall: 0.8315602836879432
# F1 score: 0.7758478081058726
# Fold 5: 0.7018701870187019
# Average score is: 0.7327883557586528 for lam =  0.001 and learning rate = 0.001 with number of epochs: 100
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7527472527472527
# Precision: 0.7831125827814569
# Recall: 0.8342151675485009
# F1 score: 0.8078565328778822
# Fold 1: 0.7527472527472527
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7296703296703296
# Precision: 0.7871287128712872
# Recall: 0.803030303030303
# F1 score: 0.795
# Fold 2: 0.7296703296703296
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7447744774477447
# Precision: 0.7717569786535303
# Recall: 0.8348134991119005
# F1 score: 0.8020477815699658
# Fold 3: 0.7447744774477447
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7315731573157316
# Precision: 0.7872696817420436
# Recall: 0.8006814310051107
# F1 score: 0.793918918918919
# Fold 4: 0.7315731573157316
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7117711771177118
# Precision: 0.7178729689807977
# Recall: 0.8725314183123878
# F1 score: 0.7876823338735818
# Fold 5: 0.7117711771177118
# Average score is: 0.7341072788597541 for lam =  0.01 and learning rate = 0.01 with number of epochs: 50
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7351648351648352
# Precision: 0.7654516640253566
# Recall: 0.8385416666666666
# F1 score: 0.8003314001657001
# Fold 1: 0.7351648351648352
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7505494505494505
# Precision: 0.7828843106180665
# Recall: 0.8458904109589042
# F1 score: 0.8131687242798356
# Fold 2: 0.7505494505494505
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7304730473047305
# Precision: 0.7697478991596639
# Recall: 0.8091872791519434
# F1 score: 0.7889750215331612
# Fold 3: 0.7304730473047305
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7238723872387238
# Precision: 0.762214983713355
# Recall: 0.8167539267015707
# F1 score: 0.788542544229149
# Fold 4: 0.7238723872387238
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7337733773377337
# Precision: 0.7534883720930232
# Recall: 0.8541300527240774
# F1 score: 0.800658978583196
# Fold 5: 0.7337733773377337
# Average score is: 0.7347666195190948 for lam =  0.01 and learning rate = 0.01 with number of epochs: 100
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7274725274725274
# Precision: 0.7395833333333334
# Recall: 0.8719298245614036
# F1 score: 0.8003220611916264
# Fold 1: 0.7274725274725274
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7351648351648352
# Precision: 0.7402985074626866
# Recall: 0.8809946714031972
# F1 score: 0.8045417680454177
# Fold 2: 0.7351648351648352
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7348734873487349
# Precision: 0.7554585152838428
# Recall: 0.8766891891891891
# F1 score: 0.8115715402658327
# Fold 3: 0.7348734873487349
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7271727172717272
# Precision: 0.7420333839150227
# Recall: 0.8624338624338624
# F1 score: 0.797716150081566
# Fold 4: 0.7271727172717272
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7315731573157316
# Precision: 0.7651757188498403
# Recall: 0.8315972222222222
# F1 score: 0.7970049916805323
# Fold 5: 0.7315731573157316
# Average score is: 0.7312513449147113 for lam =  0.01 and learning rate = 0.005 with number of epochs: 50
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7472527472527473
# Precision: 0.7951612903225806
# Recall: 0.8271812080536913
# F1 score: 0.8108552631578948
# Fold 1: 0.7472527472527473
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.756043956043956
# Precision: 0.7996661101836394
# Recall: 0.8244406196213425
# F1 score: 0.8118644067796609
# Fold 2: 0.756043956043956
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7370737073707371
# Precision: 0.766721044045677
# Recall: 0.8303886925795053
# F1 score: 0.7972858354537744
# Fold 3: 0.7370737073707371
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.724972497249725
# Precision: 0.7424
# Recall: 0.8390596745027125
# F1 score: 0.7877758913412563
# Fold 4: 0.724972497249725
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.6985698569856986
# Precision: 0.7418831168831169
# Recall: 0.798951048951049
# F1 score: 0.7693602693602695
# Fold 5: 0.6985698569856986
# Average score is: 0.7327825529805729 for lam =  0.01 and learning rate = 0.005 with number of epochs: 100
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7175824175824176
# Precision: 0.7463651050080775
# Recall: 0.8220640569395018
# F1 score: 0.7823878069432684
# Fold 1: 0.7175824175824176
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7230769230769231
# Precision: 0.7612179487179487
# Recall: 0.8217993079584776
# F1 score: 0.7903494176372712
# Fold 2: 0.7230769230769231
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7282728272827282
# Precision: 0.7542242703533026
# Recall: 0.8494809688581315
# F1 score: 0.7990235964198537
# Fold 3: 0.7282728272827282
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7436743674367436
# Precision: 0.7616099071207431
# Recall: 0.861646234676007
# F1 score: 0.8085456039441249
# Fold 4: 0.7436743674367436
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7425742574257426
# Precision: 0.778675282714055
# Recall: 0.8324697754749568
# F1 score: 0.8046744574290483
# Fold 5: 0.7425742574257426
# Average score is: 0.731036158560911 for lam =  0.01 and learning rate = 0.001 with number of epochs: 50
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7208791208791209
# Precision: 0.7464114832535885
# Recall: 0.8312611012433393
# F1 score: 0.7865546218487395
# Fold 1: 0.7208791208791209
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7417582417582418
# Precision: 0.7779527559055118
# Recall: 0.8401360544217688
# F1 score: 0.8078495502861816
# Fold 2: 0.7417582417582418
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7172717271727173
# Precision: 0.7515625
# Recall: 0.8307426597582038
# F1 score: 0.7891714520098442
# Fold 3: 0.7172717271727173
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7381738173817382
# Precision: 0.7653543307086614
# Recall: 0.8452173913043478
# F1 score: 0.8033057851239671
# Fold 4: 0.7381738173817382
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7414741474147415
# Precision: 0.7619808306709265
# Recall: 0.8472468916518651
# F1 score: 0.8023549201009252
# Fold 5: 0.7414741474147415
# Average score is: 0.731911410921312 for lam =  0.01 and learning rate = 0.001 with number of epochs: 100
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7164835164835165
# Precision: 0.7090395480225988
# Recall: 0.9061371841155235
# F1 score: 0.7955625990491284
# Fold 1: 0.7164835164835165
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7241758241758242
# Precision: 0.7215909090909091
# Recall: 0.9023090586145648
# F1 score: 0.8018942383583267
# Fold 2: 0.7241758241758242
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7216721672167217
# Precision: 0.7401685393258427
# Recall: 0.8857142857142857
# F1 score: 0.8064269319051263
# Fold 3: 0.7216721672167217
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7348734873487349
# Precision: 0.7388268156424581
# Recall: 0.9073756432246999
# F1 score: 0.8144726712856044
# Fold 4: 0.7348734873487349
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.6765676567656765
# Precision: 0.6978723404255319
# Recall: 0.8586387434554974
# F1 score: 0.7699530516431925
# Fold 5: 0.6765676567656765
# Average score is: 0.7147545303980947 for lam =  0.1 and learning rate = 0.01 with number of epochs: 50
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7076923076923077
# Precision: 0.7191011235955056
# Recall: 0.8858131487889274
# F1 score: 0.7937984496124031
# Fold 1: 0.7076923076923077
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7197802197802198
# Precision: 0.7242380261248186
# Recall: 0.8847517730496454
# F1 score: 0.7964884277733439
# Fold 2: 0.7197802197802198
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.6886688668866887
# Precision: 0.6970128022759602
# Recall: 0.875
# F1 score: 0.7759303246239112
# Fold 3: 0.6886688668866887
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7293729372937293
# Precision: 0.7341772151898734
# Recall: 0.9015544041450777
# F1 score: 0.8093023255813953
# Fold 4: 0.7293729372937293
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7194719471947195
# Precision: 0.7448377581120944
# Recall: 0.8603066439522998
# F1 score: 0.7984189723320158
# Fold 5: 0.7194719471947195
# Average score is: 0.712997255769533 for lam =  0.1 and learning rate = 0.01 with number of epochs: 100
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7329670329670329
# Precision: 0.76
# Recall: 0.8636363636363636
# F1 score: 0.8085106382978724
# Fold 1: 0.7329670329670329
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7252747252747253
# Precision: 0.7376311844077961
# Recall: 0.8677248677248677
# F1 score: 0.7974068071312803
# Fold 2: 0.7252747252747253
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.6897689768976898
# Precision: 0.716012084592145
# Recall: 0.8345070422535211
# F1 score: 0.7707317073170732
# Fold 3: 0.6897689768976898
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7095709570957096
# Precision: 0.7317436661698957
# Recall: 0.8539130434782609
# F1 score: 0.7881219903691814
# Fold 4: 0.7095709570957096
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.6941694169416942
# Precision: 0.7084548104956269
# Recall: 0.8617021276595744
# F1 score: 0.7776
# Fold 5: 0.6941694169416942
# Average score is: 0.7103502218353703 for lam =  0.1 and learning rate = 0.005 with number of epochs: 50
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7274725274725274
# Precision: 0.7388362652232747
# Recall: 0.908485856905158
# F1 score: 0.8149253731343284
# Fold 1: 0.7274725274725274
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7230769230769231
# Precision: 0.7119565217391305
# Recall: 0.9290780141843972
# F1 score: 0.8061538461538461
# Fold 2: 0.7230769230769231
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7084708470847084
# Precision: 0.7050754458161865
# Recall: 0.9113475177304965
# F1 score: 0.7950502706883218
# Fold 3: 0.7084708470847084
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7172717271727173
# Precision: 0.7126917712691772
# Recall: 0.9092526690391459
# F1 score: 0.799061767005473
# Fold 4: 0.7172717271727173
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7073707370737073
# Precision: 0.7180925666199158
# Recall: 0.8873483535528596
# F1 score: 0.793798449612403
# Fold 5: 0.7073707370737073
# Average score is: 0.7167325523761168 for lam =  0.1 and learning rate = 0.005 with number of epochs: 100
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7230769230769231
# Precision: 0.7424023154848046
# Recall: 0.8739352640545145
# F1 score: 0.8028169014084507
# Fold 1: 0.7230769230769231
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7362637362637363
# Precision: 0.729106628242075
# Recall: 0.9068100358422939
# F1 score: 0.8083067092651758
# Fold 2: 0.7362637362637363
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7095709570957096
# Precision: 0.7245949926362297
# Recall: 0.8646748681898067
# F1 score: 0.7884615384615384
# Fold 3: 0.7095709570957096
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7194719471947195
# Precision: 0.7170868347338936
# Recall: 0.9061946902654867
# F1 score: 0.800625488663018
# Fold 4: 0.7194719471947195
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7205720572057206
# Precision: 0.7488855869242199
# Recall: 0.8556876061120543
# F1 score: 0.7987321711568938
# Fold 5: 0.7205720572057206
# Average score is: 0.7217911241673619 for lam =  0.1 and learning rate = 0.001 with number of epochs: 50
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7032967032967034
# Precision: 0.7159090909090909
# Recall: 0.8780487804878049
# F1 score: 0.7887323943661972
# Fold 1: 0.7032967032967034
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7175824175824176
# Precision: 0.7242380261248186
# Recall: 0.8816254416961131
# F1 score: 0.7952191235059761
# Fold 2: 0.7175824175824176
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7304730473047305
# Precision: 0.7430249632892805
# Recall: 0.8784722222222222
# F1 score: 0.8050914876690533
# Fold 3: 0.7304730473047305
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7348734873487349
# Precision: 0.7360114777618364
# Recall: 0.9
# F1 score: 0.8097868981846882
# Fold 4: 0.7348734873487349
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Accuracy: 0.7227722772277227
# Precision: 0.7426470588235294
# Recall: 0.8676975945017182
# F1 score: 0.8003169572107766
# Fold 5: 0.7227722772277227
# Average score is: 0.7217995865520619 for lam =  0.1 and learning rate = 0.001 with number of epochs: 100
# Best score is:  0.7374107520642175 with lam =  0.001 with lr =  0.01 with epochs =  50
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Accuracy: 0.7305327868852459
# Precision: 0.7540263543191801
# Recall: 0.8442622950819673
# F1 score: 0.7965970610982213
# best learning rate:  0.01 best epoch:  50 best lam:  0.001

# %% [markdown]
# Kernel Function
# -polynomial function
# -Gaussian function

# %%
def kernel_polynomial_function(x, x_1, c = 1, d = 2):
  #the kernel function have to map the features in high dimensional space and make the dot product
  return (c + np.dot(x, x_1)) ** d

def kernel_gaussian_function(X, Y, sigma):
  diff = X - Y
  sqr_dist = np.dot(diff, diff)
  K = np.exp(-sigma * sqr_dist)
  return K

# %% [markdown]
# Extend the svm and the lr model in a kernelized form

# %%
class kernel_model(Model):
  def __init__(self, X, Y, kernel_function, kernel_params, model):
    self.X = X
    self.Y = Y
    self.kernel_params = kernel_params
    self.alpha = np.zeros(len(X))
    self.kernel_function = kernel_function
    self.b = 0
    self.K = None
    self.epochs = []
    self.loss = []
    self.acc = []
    self.val_loss = []
    self.val_acc = []
    self.val_epochs = []
    self.model = model

  def training(self, learning_rate, epochs, lam, X_val = None, Y_val = None):
    if hasattr(self.X, 'values'):
      self.X = self.X.values

    self.Y = np.array(self.Y).ravel()

    # 1. Precompute the Kernel Matrix, which tell us the similarity in the new space between all the points
    n_samples = len(self.X)
    print(f"Precomputing Kernel Matrix ({n_samples}x{n_samples})... this might take a minute.")
    self.K = np.zeros((n_samples, n_samples))

    for i in range(n_samples):
        for j in range(i, n_samples):
            k_val = self.kernel_function(self.X[i], self.X[j], **self.kernel_params)
            self.K[i, j] = k_val
            self.K[j, i] = k_val

    print("Kernel Matrix computed. Starting training...")

    initial_lr = learning_rate
    if self.model == "SVM":
      for epoch in range(epochs):
        epoch_loss = 0
        epoch_acc = 0
        #here i add a learning rate that change with time
        learning_rate = initial_lr / (1 + epoch*0.05)
        for i in range(len(self.X)):
          loss_step, correct = self.training_step_svm(i, learning_rate, lam)
          epoch_loss += loss_step
          epoch_acc += correct

        self.loss.append(epoch_loss/len(self.X))
        self.epochs.append(epoch)
        self.acc.append(epoch_acc/len(self.X))


        if epoch % 10 == 0: # Print every 10 epochs
          #self.acc.append(self.accuracy(self.X, self.Y))
          print("Epoch:", epoch)
          if X_val is not None and Y_val is not None:
            epoch_val_loss, epoch_val_acc = self.evaluate(X_val, Y_val)
            self.val_loss.append(epoch_val_loss)
            self.val_acc.append(epoch_val_acc)
            self.val_epochs.append(epoch)
    else:
      for epoch in range(epochs):
        epoch_loss = 0
        epoch_acc = 0
        #here i try adding a learning rate that change with time
        learning_rate = initial_lr / (1 + epoch*0.05)
        for i in range(len(self.X)):
          loss_step, correct = self.training_step_lr(i, learning_rate, lam)
          epoch_loss += loss_step
          epoch_acc += correct

        self.loss.append(epoch_loss/len(self.X))
        self.epochs.append(epoch)
        self.acc.append(epoch_acc/len(self.X))


        if epoch % 10 == 0: # Print every 10 epochs
          #self.acc.append(self.accuracy(self.X, self.Y))
          print("Epoch:", epoch)
          if X_val is not None and Y_val is not None:
            epoch_val_loss, epoch_val_acc = self.evaluate(X_val, Y_val)
            self.val_loss.append(epoch_val_loss)
            self.val_acc.append(epoch_val_acc)
            self.val_epochs.append(epoch)

  def training_step_svm(self, i, learning_rate, lam):
    y = self.Y[i]

    # 2. Vectorized calculation of 'z' using the precomputed Kernel Matrix
    # z = sum(alpha_j * y_j * K_ij) + b
    z = np.dot(self.alpha * self.Y, self.K[i]) + self.b

    condition = y * z

    #by the hinge loss we know
    loss = max(0, 1 - condition)
    regularization = lam/2 * (self.alpha[i] * self.alpha[i])
    total_loss = loss + regularization

    if condition > 0:
      correct = 1
    else:
      correct = 0

    #condition correct, update just using the regularization term, else also use the derivative of hinge loss
    #alpha shrink to keep the alphas low
    self.alpha = self.alpha - learning_rate * (lam * self.alpha)
    #i double "punish" the alpha[i] only if it classify incorrectly, else i just shrink parameters
    if condition < 1:
      self.alpha[i] = self.alpha[i] + learning_rate
      self.b = self.b + learning_rate * y

    return loss, correct

  def training_step_lr(self, i, learning_rate, lam):
    y = self.Y[i]

    z = np.dot(self.alpha * self.Y, self.K[i]) + self.b
    exp_term = np.exp(np.clip(-y * z, -500, 500))

    loss = np.log2(1 + exp_term)
    regularization = (lam / 2)*np.dot(self.alpha[i],self.alpha[i])
    tot_loss = loss + regularization
    #calculate prob that estimate is correct
    sigma = 1 / (1 + exp_term)
    if z*y > 0:
      correct = 1
    else:
      correct = 0

    #gradient loss and alpha update
    #gradient = (-1/np.log2(1 + np.exp(-y * z))) * (-y * np.exp(-y * z)) + lam * self.alpha[i]
    self.alpha = self.alpha - learning_rate * (lam * self.alpha)
    error = 1 - sigma
    self.alpha[i] = self.alpha[i] + learning_rate * error
    self.b = self.b + learning_rate * y * error

    return loss, correct

  def predict(self, X_test):
      predictions = []
      X_train = self.X # stored from training

      if hasattr(X_test, 'values'):
        X_test = X_test.values

      # For prediction on new data, we have to compute the kernel against all training points
      for i in range(len(X_test)):
        x = X_test[i]
        z = self.b

        if self.model == "SVM":
          # z = sum(alpha_j * y_j * K(x_train_j, x_new))
          for j in range(len(X_train)):
            # Only compute for non-zero alphas (Support Vectors) to save time
            if self.alpha[j] != 0:
                #compute the similarity between the two points
                k = self.kernel_function(X_train[j], x, **self.kernel_params)
                z += self.alpha[j] * self.Y[j] * k

          #z positive mean +1, else -1
          predictions.append(np.sign(z))
        else:
          for j in range(len(X_train)):
            # Only compute for non-zero alphas (Support Vectors) to save time
            #if abs(self.alpha[j]) > 0.001:
              k = self.kernel_function(X_train[j], x, **self.kernel_params)
              z += self.alpha[j] * self.Y[j] * k
          #Note that this is equivalent to do the sigmoid function, for z >= 0 it is: 1/(1+e^z) >= 0.5
          if z >= 0:
            prediction = 1
          else:
            prediction = -1
          predictions.append(prediction)

      return np.array(predictions).ravel()

  def evaluate(self, X_val, Y_val):
    if hasattr(X_val, 'values'):
      X_val = X_val.values

    Y_val = np.array(Y_val).ravel()

    val_loss = 0
    val_acc = 0
    for i in range(len(X_val)):
      x = X_val[i]
      y = Y_val[i]
      z = self.b
      for j in range(len(self.X)):
        if self.alpha[j] != 0:
          k = self.kernel_function(self.X[j], x, **self.kernel_params)
          z += self.alpha[j] * self.Y[j] * k

      if self.model == "SVM":
        val_loss += max(0, 1 - y * z)
        #if concordant, then classification is correct
        if y * z > 0:
          val_acc += 1
      else:
        exp_term = np.exp(np.clip(-y * z, -500, 500))
        val_loss += np.log2(1 + exp_term)
        if y * z > 0:
          val_acc += 1

    return val_loss/len(X_val), val_acc/len(X_val)

# %% [markdown]
# Training of the various kind of models. While the initialization is done in the same block, the training is executed in different blocks, because it requires time to train just once

# %%
#Running the models
split_ratio = 0.7
eval_ratio = 0.15
test_ratio = 0.15
X_train, y_train, X_eval, y_eval, X_test, y_test = split_data(X, y, split_ratio,eval_ratio, test_ratio)
param_poly = {'c': 1, 'd': 2}
param_gaus = {'sigma': 0.1}
model_poly = kernel_model(X_train, y_train, kernel_polynomial_function, param_poly, "SVM")
model_gaus = kernel_model(X_train, y_train, kernel_gaussian_function, param_gaus, "SVM")
model_lr_poly = kernel_model(X_train, y_train, kernel_polynomial_function, param_poly, "LR")
model_lr_gaus = kernel_model(X_train, y_train, kernel_gaussian_function, param_gaus, "LR")

# %% [markdown]
# Each training was done on different block to speed up.

# %%
model_poly.training(learning_rate=0.001, epochs=101, lam=0.001, X_val = X_eval, Y_val = y_eval)
# Out:
# Precomputing Kernel Matrix (4547x4547)... this might take a minute.
# Kernel Matrix computed. Starting training...
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Epoch: 100

# %%
model_gaus.training(learning_rate=0.001, epochs=101, lam=0.001, X_val = X_eval, Y_val = y_eval)
# Out:
# Precomputing Kernel Matrix (4547x4547)... this might take a minute.
# Kernel Matrix computed. Starting training...
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Epoch: 100

# %%
model_lr_poly.training(learning_rate=0.001, epochs=101, lam=0.001, X_val = X_eval, Y_val = y_eval)
# Out:
# Precomputing Kernel Matrix (4547x4547)... this might take a minute.
# Kernel Matrix computed. Starting training...
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Epoch: 100

# %%
model_lr_gaus.training(learning_rate=0.001, epochs=101, lam=0.001, X_val = X_eval, Y_val = y_eval)
# Out:
# Precomputing Kernel Matrix (4547x4547)... this might take a minute.
# Kernel Matrix computed. Starting training...
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40
# Epoch: 50
# Epoch: 60
# Epoch: 70
# Epoch: 80
# Epoch: 90
# Epoch: 100

# %% [markdown]
# Plottting the graph. The loss and the accuracy are here showed both during training and test.

# %%
import matplotlib.pyplot as plt

plt.plot(model_poly.epochs, model_poly.loss, label = "Training Loss")

plt.plot(model_poly.val_epochs, model_poly.val_loss, label="Validation Loss", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.title('loss through time')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(model_poly.epochs, model_poly.acc, label = "Training Acc")

plt.plot(model_poly.val_epochs, model_poly.val_acc, label="Validation Acc", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy through time')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(model_gaus.epochs, model_gaus.loss, label = "Training Loss")

plt.plot(model_gaus.val_epochs, model_gaus.val_loss, label="Validation Loss", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.title('loss through time')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(model_gaus.epochs, model_gaus.acc, label = "Training accuracy")

plt.plot(model_gaus.val_epochs, model_gaus.val_acc, label="Validation accuracy", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy through time')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(model_lr_poly.epochs, model_lr_poly.loss, label = "Training Loss")

plt.plot(model_lr_poly.val_epochs, model_lr_poly.val_loss, label="Validation Loss", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.title('loss through time')
plt.show()

# %%
plt.plot(model_lr_poly.epochs, model_lr_poly.acc, label = "Training Accuracy")

plt.plot(model_lr_poly.val_epochs, model_lr_poly.val_acc, label="Validation Loss", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy through time')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(model_lr_gaus.epochs, model_lr_gaus.loss, label = "Training Loss")

plt.plot(model_lr_gaus.val_epochs, model_lr_gaus.val_loss, label="Validation Loss", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Average Loss')
plt.title('loss through time')
plt.show()

# %%
plt.plot(model_lr_gaus.epochs, model_lr_gaus.acc, label = "Training Accuracy")

plt.plot(model_lr_gaus.val_epochs, model_lr_gaus.val_acc, label="Validation Loss", color="orange")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy through time')
plt.show()

# %% [markdown]
# Metric of the various models

# %%
predictions = model_poly.predict(X_test)
final_acc, final_prec, final_rec, final_f1 = performance_metric(predictions, y_test.values.ravel())
# Out:
# Accuracy: 0.7622950819672131
# Precision: 0.7784256559766763
# Recall: 0.8697068403908795
# F1 score: 0.8215384615384614

# %%
predictions = model_gaus.predict(X_test)
final_acc, final_prec, final_rec, final_f1 = performance_metric(predictions, y_test.values.ravel())
# Out:
# Accuracy: 0.7305327868852459
# Precision: 0.7264516129032258
# Recall: 0.9169381107491856
# F1 score: 0.8106551475881929

# %%
predictions = model_lr_poly.predict(X_test)
final_acc, final_prec, final_rec, final_f1 = performance_metric(predictions, y_test.values.ravel())
# Out:
# Accuracy: 0.7704918032786885
# Precision: 0.7867647058823529
# Recall: 0.8713355048859935
# F1 score: 0.8268933539412675

# %%
predictions = model_lr_gaus.predict(X_test)
final_acc, final_prec, final_rec, final_f1 = performance_metric(predictions, y_test.values.ravel())
# Out:
# Accuracy: 0.7407786885245902
# Precision: 0.7353324641460235
# Recall: 0.9185667752442996
# F1 score: 0.8167994207096307

# %% [markdown]
# Confusion Matrix. Given a prediction and the real results we can confront where the model fail and get some interesting conclusions, like how dataset was build.

# %%
import numpy as np
import matplotlib.pyplot as plt

def confusion_matrix(y, y_pred):
  true_positive = 0
  true_negative = 0
  false_positive = 0
  false_negative = 0
  for yt, yp in zip(y, y_pred):
    if yt == 1 and yp == 1:
      true_positive += 1
    elif yt == 1 and yp == -1:
      false_negative += 1
    elif yt == -1 and yp == 1:
      false_positive += 1
    else:
      true_negative += 1

  conf_matrix = np.array([[true_negative, false_positive], [false_negative, true_positive]])
  fig, ax = plt.subplots(figsize=(6, 5))
  cax = ax.imshow(conf_matrix, cmap='Blues')
  plt.colorbar(cax)

  for i in range(2):
    for j in range(2):
      ax.text(j, i, str(conf_matrix[i, j]), va='center', ha='center', color='black', fontsize=16, fontweight='bold')

  plt.xticks([0, 1], ['Bad wine', 'Good wine'])

  plt.yticks([0, 1], ['Bad wine', 'Good wine'])

  plt.xlabel('Model prediction')

  plt.ylabel('Real data')

  plt.title('Confusion matrix')

  plt.show()

# %%
confusion_matrix(y_test.values.ravel(), pred_svm)

# %% [markdown]
# OPTIONAL: DATA AUGMENTATION
# Data are augmented using Smote. A random point is selected and the euclidean distance is calculated with respect to all the other points, after that a k number of closest points are selected and a neighbor between them is chosen randomly. using the data point and the neighbor a new point is created with feature that are between the point and the neighbor.
# The successive block of code is done to augment data of many times.
# Data are undersampled by removing points with label 1

# %%
#get a random data point and his neighbor (using Euclidean distance)
def get_random_data_point(X):
  rd_num = random.randint(0,len(X) - 1)
  #sample is the value that i use to generate synthetic data
  sample = X.iloc[rd_num].values
  label = y.iloc[rd_num].values
  distances = []
  for i in range(len(X)):
    distances.append(np.sqrt(np.sum(np.square(X.iloc[i].values - sample))))
  return distances, sample, label

#Check the closest neighboors
def get_closest_neighboors(distances,sample, X ,k):
  #Sort the indices of the closest neighboors
  nearest_indices = np.argsort(distances)[1:k+1]
  #Now i produce a synthetic data (SMOTE)
  random_neighboor_index = np.random.choice(nearest_indices)
  neighbor = X.iloc[random_neighboor_index].values
  synthetic_data = sample + (neighbor - sample) * np.random.uniform(0, 1)

  print("The sample was:")
  print(pd.Series(sample, index=X.columns))  # Convert to Series with column names
  print("\nThe label was:")
  print(pd.Series(label, index=y.columns))
  print("\nThe closest neighbor was:")
  print(pd.Series(neighbor, index=X.columns))
  print("\nThe synthetic data is:")
  print(pd.Series(synthetic_data, index=X.columns))
  print("\n" + "Another data" + "\n")

  return synthetic_data

# %%
#Here i execute the code above as many times as i want to get n artificial samples
n = 500
artificial_data = []
artificial_labels = []
smp = 0
while smp < n:
  distances, sample , label = get_random_data_point(X)
  #The if is used to create negative sample.
  if label < 6:
    new_data = get_closest_neighboors(distances,sample, X ,5)
    artificial_data.append(new_data)
    artificial_labels.append(label)
    smp += 1

# Here i convert the data to be sure it's dataframe
artificial_df = pd.DataFrame(artificial_data, columns=X.columns)
artificial_y = pd.DataFrame(artificial_labels, columns=y.columns)
#Concatenation of the two dataframe (original and synthetic)
X_augmented = pd.concat([X, artificial_df], ignore_index=True)
y_augmented = pd.concat([y, artificial_y], ignore_index=True)

#Some examples
print(artificial_df.head())
print(artificial_y.head())
# Out:
# Output streaming troncato alle ultime 5000 righe.
# The closest neighbor was:
# fixed_acidity          -0.937423
# volatile_acidity       -0.605370
# citric_acid            -0.334668
# residual_sugar         -0.744721
# chlorides              -0.229319
# free_sulfur_dioxide     0.533803
# total_sulfur_dioxide    0.959902
# density                -0.299010
# pH                      2.621472
# sulphates               0.058679
# alcohol                -0.412338
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -1.420958
# volatile_acidity       -0.496581
# citric_acid            -0.581170
# residual_sugar         -0.132995
# chlorides              -0.587187
# free_sulfur_dioxide     0.937436
# total_sulfur_dioxide    0.801462
# density                 0.119089
# pH                      3.624011
# sulphates              -0.121865
# alcohol                -0.036921
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.011807
# volatile_acidity       -1.212769
# citric_acid             0.215849
# residual_sugar         -0.891847
# chlorides              -0.571847
# free_sulfur_dioxide    -0.874695
# total_sulfur_dioxide   -0.756249
# density                -0.299010
# pH                      1.501980
# sulphates              -0.949346
# alcohol                -0.496181
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.142462
# volatile_acidity       -1.212769
# citric_acid            -0.128224
# residual_sugar         -0.870829
# chlorides              -0.657479
# free_sulfur_dioxide    -0.311296
# total_sulfur_dioxide   -0.437788
# density                -0.672509
# pH                      1.937338
# sulphates              -0.949346
# alcohol                 0.090717
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.084576
# volatile_acidity       -1.212769
# citric_acid             0.000882
# residual_sugar         -0.878716
# chlorides              -0.625348
# free_sulfur_dioxide    -0.522700
# total_sulfur_dioxide   -0.557283
# density                -0.532361
# pH                      1.773979
# sulphates              -0.949346
# alcohol                -0.129504
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity            1.145213
# volatile_acidity         2.674584
# citric_acid              1.316884
# residual_sugar          -0.786757
# chlorides               10.246338
# free_sulfur_dioxide     -1.043715
# total_sulfur_dioxide    -0.880095
# density                  0.511348
# pH                      -1.358944
# sulphates                4.292382
# alcohol                 -1.083079
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity            1.453752
# volatile_acidity         2.553104
# citric_acid              2.486733
# residual_sugar          -0.786757
# chlorides               10.217794
# free_sulfur_dioxide     -0.705676
# total_sulfur_dioxide    -0.915479
# density                  0.608058
# pH                      -1.980884
# sulphates                5.367609
# alcohol                 -1.166921
# dtype: float64
#
# The synthetic data is:
# fixed_acidity            1.403888
# volatile_acidity         2.572736
# citric_acid              2.297672
# residual_sugar          -0.786757
# chlorides               10.222408
# free_sulfur_dioxide     -0.760307
# total_sulfur_dioxide    -0.909761
# density                  0.592428
# pH                      -1.880371
# sulphates                5.193840
# alcohol                 -1.153371
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.011807
# volatile_acidity       -0.423150
# citric_acid            -0.334668
# residual_sugar         -0.639630
# chlorides              -0.229319
# free_sulfur_dioxide    -0.029596
# total_sulfur_dioxide    0.588364
# density                -0.365706
# pH                     -0.737004
# sulphates              -0.142926
# alcohol                -1.083079
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.142462
# volatile_acidity       -0.119451
# citric_acid            -0.334668
# residual_sugar         -0.849811
# chlorides              -0.200775
# free_sulfur_dioxide     0.421123
# total_sulfur_dioxide    1.012979
# density                -0.449077
# pH                     -1.172362
# sulphates              -0.075725
# alcohol                -0.999236
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.090914
# volatile_acidity       -0.220931
# citric_acid            -0.334668
# residual_sugar         -0.779580
# chlorides              -0.210313
# free_sulfur_dioxide     0.270517
# total_sulfur_dioxide    0.871095
# density                -0.421219
# pH                     -1.026889
# sulphates              -0.098180
# alcohol                -1.027252
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           3.459253
# volatile_acidity        0.913127
# citric_acid             1.179255
# residual_sugar         -0.681666
# chlorides               0.769722
# free_sulfur_dioxide    -1.438095
# total_sulfur_dioxide   -1.782400
# density                 1.768571
# pH                     -0.177258
# sulphates              -0.680540
# alcohol                -1.083079
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           2.996445
# volatile_acidity        0.062769
# citric_acid             1.110440
# residual_sugar         -0.492504
# chlorides               0.969530
# free_sulfur_dioxide    -1.438095
# total_sulfur_dioxide   -1.676247
# density                 1.301698
# pH                     -0.301646
# sulphates              -0.008523
# alcohol                 0.006874
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           3.074049
# volatile_acidity        0.205357
# citric_acid             1.121979
# residual_sugar         -0.524223
# chlorides               0.936026
# free_sulfur_dioxide    -1.438095
# total_sulfur_dioxide   -1.694047
# density                 1.379983
# pH                     -0.280789
# sulphates              -0.121207
# alcohol                -0.175890
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -1.014558
# volatile_acidity       -0.726850
# citric_acid            -0.128224
# residual_sugar         -0.870829
# chlorides              -0.115143
# free_sulfur_dioxide     0.646483
# total_sulfur_dioxide   -0.526249
# density                -1.336136
# pH                      0.569070
# sulphates              -0.411733
# alcohol                 0.887221
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -1.091693
# volatile_acidity       -0.483890
# citric_acid            -0.197039
# residual_sugar         -0.933884
# chlorides              -0.400583
# free_sulfur_dioxide     0.252103
# total_sulfur_dioxide   -0.260865
# density                -1.419506
# pH                      0.880040
# sulphates              -0.344531
# alcohol                 0.761457
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -1.031778
# volatile_acidity       -0.672609
# citric_acid            -0.143587
# residual_sugar         -0.884906
# chlorides              -0.178867
# free_sulfur_dioxide     0.558438
# total_sulfur_dioxide   -0.467002
# density                -1.354748
# pH                      0.638494
# sulphates              -0.396730
# alcohol                 0.859145
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           1.453752
# volatile_acidity        0.670167
# citric_acid             0.215849
# residual_sugar         -0.639630
# chlorides               0.684090
# free_sulfur_dioxide    -0.423976
# total_sulfur_dioxide   -0.667787
# density                 1.335046
# pH                      1.004428
# sulphates               0.596292
# alcohol                -0.831551
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           1.376617
# volatile_acidity        0.730907
# citric_acid            -0.059409
# residual_sugar         -0.555558
# chlorides               1.055162
# free_sulfur_dioxide    -0.649336
# total_sulfur_dioxide   -0.313942
# density                 1.151631
# pH                      0.631264
# sulphates               0.663493
# alcohol                -0.831551
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           1.452737
# volatile_acidity        0.670967
# citric_acid             0.212227
# residual_sugar         -0.638524
# chlorides               0.688973
# free_sulfur_dioxide    -0.426942
# total_sulfur_dioxide   -0.663131
# density                 1.332632
# pH                      0.999517
# sulphates               0.597176
# alcohol                -0.831551
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.474615
# volatile_acidity       -0.483890
# citric_acid            -0.472297
# residual_sugar          1.294035
# chlorides              -0.314951
# free_sulfur_dioxide     0.815503
# total_sulfur_dioxide    1.101440
# density                 0.738115
# pH                      0.693458
# sulphates              -0.680540
# alcohol                -0.580023
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.628884
# volatile_acidity       -0.605370
# citric_acid            -0.265853
# residual_sugar          1.273017
# chlorides              -0.172231
# free_sulfur_dioxide     0.195763
# total_sulfur_dioxide    0.836056
# density                 0.734780
# pH                      0.569070
# sulphates              -0.546136
# alcohol                -0.831551
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.507957
# volatile_acidity       -0.510145
# citric_acid            -0.427679
# residual_sugar          1.289492
# chlorides              -0.284105
# free_sulfur_dioxide     0.681561
# total_sulfur_dioxide    1.044084
# density                 0.737394
# pH                      0.666575
# sulphates              -0.651492
# alcohol                -0.634385
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.088942
# volatile_acidity       -0.666110
# citric_acid            -0.541112
# residual_sugar         -0.009087
# chlorides              -0.486215
# free_sulfur_dioxide     1.660602
# total_sulfur_dioxide    1.419901
# density                 0.034471
# pH                     -0.177258
# sulphates               1.671518
# alcohol                -0.412338
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.320346
# volatile_acidity       -0.909070
# citric_acid            -0.609926
# residual_sugar         -0.072142
# chlorides              -0.628935
# free_sulfur_dioxide     2.280341
# total_sulfur_dioxide    1.561439
# density                -0.165618
# pH                      0.071518
# sulphates               1.066703
# alcohol                -0.328496
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.102903
# volatile_acidity       -0.680768
# citric_acid            -0.545263
# residual_sugar         -0.012891
# chlorides              -0.494825
# free_sulfur_dioxide     1.697991
# total_sulfur_dioxide    1.428440
# density                 0.022399
# pH                     -0.162249
# sulphates               1.635029
# alcohol                -0.407280
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -1.477366
# volatile_acidity        1.581266
# citric_acid             0.147035
# residual_sugar         -0.849811
# chlorides              -0.714567
# free_sulfur_dioxide    -1.550775
# total_sulfur_dioxide   -0.986248
# density                -2.053119
# pH                      0.320294
# sulphates              -1.016548
# alcohol                 2.102938
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -1.245962
# volatile_acidity        0.427208
# citric_acid            -0.541112
# residual_sugar         -0.744721
# chlorides              -0.628935
# free_sulfur_dioxide    -1.156395
# total_sulfur_dioxide   -1.110094
# density                -2.183177
# pH                      0.631264
# sulphates              -0.210128
# alcohol                 2.522151
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -1.437690
# volatile_acidity        1.383394
# citric_acid             0.029047
# residual_sugar         -0.831793
# chlorides              -0.699885
# free_sulfur_dioxide    -1.483155
# total_sulfur_dioxide   -1.007482
# density                -2.075419
# pH                      0.373612
# sulphates              -0.878281
# alcohol                 2.174815
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           1.068078
# volatile_acidity        1.095347
# citric_acid             0.422293
# residual_sugar         -0.828793
# chlorides               1.140794
# free_sulfur_dioxide    -1.438095
# total_sulfur_dioxide   -1.729324
# density                 0.654745
# pH                     -0.115064
# sulphates              -0.075725
# alcohol                -0.915394
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           1.608021
# volatile_acidity        0.548688
# citric_acid             0.835181
# residual_sugar         -0.744721
# chlorides               0.826810
# free_sulfur_dioxide    -1.212735
# total_sulfur_dioxide   -1.658554
# density                 0.794807
# pH                      0.382488
# sulphates               0.125880
# alcohol                -0.831551
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           1.210756
# volatile_acidity        0.950894
# citric_acid             0.531398
# residual_sugar         -0.806577
# chlorides               1.057825
# free_sulfur_dioxide    -1.378544
# total_sulfur_dioxide   -1.710623
# density                 0.691756
# pH                      0.016412
# sulphates              -0.022451
# alcohol                -0.893239
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.296732
# volatile_acidity       -0.605370
# citric_acid             0.835181
# residual_sugar         -0.345377
# chlorides              -0.543303
# free_sulfur_dioxide     1.040862
# total_sulfur_dioxide    0.535287
# density                -1.199408
# pH                     -0.985780
# sulphates              -1.083749
# alcohol                 0.929142
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.373866
# volatile_acidity       -0.423150
# citric_acid             1.179255
# residual_sugar         -0.345377
# chlorides              -0.543303
# free_sulfur_dioxide     0.871842
# total_sulfur_dioxide    0.411441
# density                -1.179400
# pH                     -1.110168
# sulphates              -1.016548
# alcohol                 0.929142
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.331269
# volatile_acidity       -0.523780
# citric_acid             0.989242
# residual_sugar         -0.345377
# chlorides              -0.543303
# free_sulfur_dioxide     0.965183
# total_sulfur_dioxide    0.479834
# density                -1.190449
# pH                     -1.041476
# sulphates              -1.053659
# alcohol                 0.929142
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -1.014558
# volatile_acidity       -0.605370
# citric_acid            -0.265853
# residual_sugar         -0.870829
# chlorides              -0.686023
# free_sulfur_dioxide     0.308443
# total_sulfur_dioxide   -0.367019
# density                -1.936401
# pH                     -0.861392
# sulphates               0.730695
# alcohol                 2.019096
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.937423
# volatile_acidity       -0.848330
# citric_acid             0.422293
# residual_sugar         -0.870829
# chlorides              -0.628935
# free_sulfur_dioxide     0.364783
# total_sulfur_dioxide   -0.207788
# density                -2.016437
# pH                     -0.674810
# sulphates              -0.075725
# alcohol                 1.851411
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.972837
# volatile_acidity       -0.736782
# citric_acid             0.106350
# residual_sugar         -0.870829
# chlorides              -0.655145
# free_sulfur_dioxide     0.338916
# total_sulfur_dioxide   -0.280894
# density                -1.979691
# pH                     -0.760474
# sulphates               0.294520
# alcohol                 1.928398
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.088942
# volatile_acidity       -0.544630
# citric_acid            -0.265853
# residual_sugar         -0.891847
# chlorides              -0.457671
# free_sulfur_dioxide     0.026743
# total_sulfur_dioxide   -0.083942
# density                -0.985981
# pH                     -0.239452
# sulphates              -0.008523
# alcohol                 0.509930
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.011807
# volatile_acidity       -0.544630
# citric_acid             0.009405
# residual_sugar         -0.828793
# chlorides              -0.058055
# free_sulfur_dioxide    -0.367636
# total_sulfur_dioxide   -0.190096
# density                -1.052677
# pH                     -0.301646
# sulphates              -0.344531
# alcohol                 0.509930
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.024665
# volatile_acidity       -0.544630
# citric_acid            -0.036479
# residual_sugar         -0.839304
# chlorides              -0.124668
# free_sulfur_dioxide    -0.301895
# total_sulfur_dioxide   -0.172401
# density                -1.041559
# pH                     -0.291279
# sulphates              -0.288521
# alcohol                 0.509930
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.937423
# volatile_acidity       -1.030549
# citric_acid             0.078220
# residual_sugar          0.117021
# chlorides              -0.571847
# free_sulfur_dioxide    -0.029596
# total_sulfur_dioxide   -0.083942
# density                -0.359037
# pH                      0.631264
# sulphates               0.327485
# alcohol                -0.300548
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.937423
# volatile_acidity       -1.030549
# citric_acid             0.078220
# residual_sugar          0.117021
# chlorides              -0.571847
# free_sulfur_dioxide    -0.029596
# total_sulfur_dioxide   -0.083942
# density                -0.359037
# pH                      0.631264
# sulphates               0.327485
# alcohol                -0.286575
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.937423
# volatile_acidity       -1.030549
# citric_acid             0.078220
# residual_sugar          0.117021
# chlorides              -0.571847
# free_sulfur_dioxide    -0.029596
# total_sulfur_dioxide   -0.083942
# density                -0.359037
# pH                      0.631264
# sulphates               0.327485
# alcohol                -0.292273
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.759540
# volatile_acidity       -0.180191
# citric_acid             0.559923
# residual_sugar         -0.681666
# chlorides               0.056121
# free_sulfur_dioxide    -1.381755
# total_sulfur_dioxide   -1.870862
# density                 0.221220
# pH                      0.569070
# sulphates               0.999502
# alcohol                 0.593772
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.528136
# volatile_acidity       -0.058711
# citric_acid             0.628737
# residual_sugar         -0.828793
# chlorides              -0.000967
# free_sulfur_dioxide    -1.381755
# total_sulfur_dioxide   -1.428555
# density                -0.245653
# pH                      0.444682
# sulphates               1.201107
# alcohol                 0.426087
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.632329
# volatile_acidity       -0.113409
# citric_acid             0.597753
# residual_sugar         -0.762547
# chlorides               0.024738
# free_sulfur_dioxide    -1.381755
# total_sulfur_dioxide   -1.627710
# density                -0.035437
# pH                      0.500689
# sulphates               1.110331
# alcohol                 0.501590
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.296732
# volatile_acidity        2.006445
# citric_acid            -1.229258
# residual_sugar         -0.828793
# chlorides               0.512826
# free_sulfur_dioxide    -0.311296
# total_sulfur_dioxide    0.924517
# density                -0.332358
# pH                     -1.047974
# sulphates              -0.142926
# alcohol                -0.999236
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.011807
# volatile_acidity        1.277566
# citric_acid            -1.573332
# residual_sugar         -0.828793
# chlorides               1.483323
# free_sulfur_dioxide    -0.818356
# total_sulfur_dioxide    0.623749
# density                -0.299010
# pH                     -0.923586
# sulphates               0.260284
# alcohol                -1.083079
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.081684
# volatile_acidity        1.498426
# citric_acid            -1.469073
# residual_sugar         -0.828793
# chlorides               1.189250
# free_sulfur_dioxide    -0.664710
# total_sulfur_dioxide    0.714885
# density                -0.309115
# pH                     -0.961277
# sulphates               0.138106
# alcohol                -1.057673
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.628884
# volatile_acidity       -0.969809
# citric_acid             2.899621
# residual_sugar          1.357089
# chlorides              -0.286407
# free_sulfur_dioxide     1.322562
# total_sulfur_dioxide    0.924517
# density                 1.034913
# pH                      2.248308
# sulphates               0.999502
# alcohol                -0.328496
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.628884
# volatile_acidity       -0.969809
# citric_acid             2.899621
# residual_sugar          1.357089
# chlorides              -0.286407
# free_sulfur_dioxide     1.322562
# total_sulfur_dioxide    0.924517
# density                 1.034913
# pH                      2.248308
# sulphates               0.999502
# alcohol                -0.328496
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.628884
# volatile_acidity       -0.969809
# citric_acid             2.899621
# residual_sugar          1.357089
# chlorides              -0.286407
# free_sulfur_dioxide     1.322562
# total_sulfur_dioxide    0.924517
# density                 1.034913
# pH                      2.248308
# sulphates               0.999502
# alcohol                -0.328496
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           2.919311
# volatile_acidity       -0.240931
# citric_acid             1.798587
# residual_sugar         -0.702685
# chlorides              -0.058055
# free_sulfur_dioxide    -1.325415
# total_sulfur_dioxide   -1.711631
# density                 1.101609
# pH                      0.569070
# sulphates               2.343535
# alcohol                 0.006874
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           2.456503
# volatile_acidity       -0.483890
# citric_acid             1.110440
# residual_sugar         -0.744721
# chlorides               0.284474
# free_sulfur_dioxide    -1.381755
# total_sulfur_dioxide   -1.870862
# density                 0.848164
# pH                      0.693458
# sulphates               2.276333
# alcohol                 0.342245
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           2.833701
# volatile_acidity       -0.285873
# citric_acid             1.671294
# residual_sugar         -0.710460
# chlorides               0.005306
# free_sulfur_dioxide    -1.335837
# total_sulfur_dioxide   -1.741086
# density                 1.054727
# pH                      0.592079
# sulphates               2.331104
# alcohol                 0.068911
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.836674
# volatile_acidity       -1.030549
# citric_acid            -0.059409
# residual_sugar         -0.828793
# chlorides              -0.200775
# free_sulfur_dioxide     0.984522
# total_sulfur_dioxide    0.659133
# density                -0.165618
# pH                     -0.612616
# sulphates               0.327485
# alcohol                -0.915394
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.759540
# volatile_acidity       -0.726850
# citric_acid            -0.128224
# residual_sugar         -0.765739
# chlorides              -0.257863
# free_sulfur_dioxide     0.928182
# total_sulfur_dioxide    1.225286
# density                -0.465751
# pH                     -0.550422
# sulphates              -0.210128
# alcohol                -0.244653
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.830175
# volatile_acidity       -1.004959
# citric_acid            -0.065208
# residual_sugar         -0.823480
# chlorides              -0.205585
# free_sulfur_dioxide     0.979775
# total_sulfur_dioxide    0.706838
# density                -0.190907
# pH                     -0.607376
# sulphates               0.282185
# alcohol                -0.858877
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.860289
# volatile_acidity       -1.303879
# citric_acid            -0.472297
# residual_sugar         -0.450467
# chlorides              -0.457671
# free_sulfur_dioxide    -1.156395
# total_sulfur_dioxide   -0.827018
# density                -0.432403
# pH                      1.999532
# sulphates               0.394687
# alcohol                -0.328496
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.628884
# volatile_acidity       -1.091289
# citric_acid            -0.472297
# residual_sugar         -0.870829
# chlorides              -0.257863
# free_sulfur_dioxide    -0.592996
# total_sulfur_dioxide   -0.685480
# density                -0.465751
# pH                      2.434890
# sulphates               0.058679
# alcohol                -0.244653
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.631216
# volatile_acidity       -1.093431
# citric_acid            -0.472297
# residual_sugar         -0.866595
# chlorides              -0.259876
# free_sulfur_dioxide    -0.598671
# total_sulfur_dioxide   -0.686905
# density                -0.465415
# pH                      2.430504
# sulphates               0.062063
# alcohol                -0.245498
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.142462
# volatile_acidity       -0.301671
# citric_acid            -0.197039
# residual_sugar         -0.807775
# chlorides              -0.314951
# free_sulfur_dioxide     1.266222
# total_sulfur_dioxide    1.136824
# density                -0.365706
# pH                      0.755652
# sulphates               0.999502
# alcohol                 0.006874
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.142462
# volatile_acidity       -0.483890
# citric_acid            -0.059409
# residual_sugar         -0.639630
# chlorides              -0.372039
# free_sulfur_dioxide     1.547922
# total_sulfur_dioxide    1.101440
# density                -0.198966
# pH                      1.253204
# sulphates               0.999502
# alcohol                 0.090717
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.142462
# volatile_acidity       -0.459501
# citric_acid            -0.077831
# residual_sugar         -0.662136
# chlorides              -0.364398
# free_sulfur_dioxide     1.510217
# total_sulfur_dioxide    1.106176
# density                -0.221284
# pH                      1.186608
# sulphates               0.999502
# alcohol                 0.079495
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.783154
# volatile_acidity       -1.152029
# citric_acid             0.972811
# residual_sugar         -0.807775
# chlorides              -0.486215
# free_sulfur_dioxide     0.421123
# total_sulfur_dioxide    0.128365
# density                -0.565795
# pH                      1.004428
# sulphates              -0.142926
# alcohol                -0.663866
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.783154
# volatile_acidity       -0.969809
# citric_acid             0.422293
# residual_sugar         -0.828793
# chlorides              -0.800199
# free_sulfur_dioxide     0.308443
# total_sulfur_dioxide    0.022211
# density                -0.565795
# pH                      1.564174
# sulphates               0.058679
# alcohol                -0.663866
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.783154
# volatile_acidity       -1.020830
# citric_acid             0.576435
# residual_sugar         -0.822908
# chlorides              -0.712286
# free_sulfur_dioxide     0.339993
# total_sulfur_dioxide    0.051934
# density                -0.565795
# pH                      1.407449
# sulphates               0.002231
# alcohol                -0.663866
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.937423
# volatile_acidity       -0.058711
# citric_acid             0.422293
# residual_sugar          0.894691
# chlorides              -0.457671
# free_sulfur_dioxide    -0.085936
# total_sulfur_dioxide    0.146057
# density                 0.234559
# pH                      1.564174
# sulphates              -0.344531
# alcohol                 0.426087
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -1.245962
# volatile_acidity       -0.969809
# citric_acid            -0.128224
# residual_sugar          0.999782
# chlorides              -0.800199
# free_sulfur_dioxide    -0.142276
# total_sulfur_dioxide    0.269903
# density                 0.234559
# pH                      1.688562
# sulphates              -0.747741
# alcohol                 0.258402
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.938817
# volatile_acidity       -0.062827
# citric_acid             0.419806
# residual_sugar          0.895166
# chlorides              -0.459218
# free_sulfur_dioxide    -0.086191
# total_sulfur_dioxide    0.146617
# density                 0.234559
# pH                      1.564736
# sulphates              -0.346353
# alcohol                 0.425330
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.474615
# volatile_acidity        0.184248
# citric_acid            -0.541112
# residual_sugar         -0.723703
# chlorides               0.227386
# free_sulfur_dioxide    -0.423976
# total_sulfur_dioxide    0.075288
# density                -0.032226
# pH                      0.631264
# sulphates               0.058679
# alcohol                -0.915394
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.474615
# volatile_acidity        0.002029
# citric_acid            -0.816370
# residual_sugar         -0.933884
# chlorides              -0.086599
# free_sulfur_dioxide    -0.254956
# total_sulfur_dioxide   -0.066250
# density                -0.445742
# pH                      0.631264
# sulphates               0.125880
# alcohol                -1.166921
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.474615
# volatile_acidity        0.162068
# citric_acid            -0.574617
# residual_sugar         -0.749286
# chlorides               0.189167
# free_sulfur_dioxide    -0.403403
# total_sulfur_dioxide    0.058060
# density                -0.082559
# pH                      0.631264
# sulphates               0.066859
# alcohol                -0.946010
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.373866
# volatile_acidity        1.702745
# citric_acid            -1.917405
# residual_sugar         -0.345377
# chlorides               0.798266
# free_sulfur_dioxide    -0.311296
# total_sulfur_dioxide   -1.251632
# density                 1.034913
# pH                      0.755652
# sulphates              -0.008523
# alcohol                -0.831551
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.836674
# volatile_acidity        1.884965
# citric_acid            -1.504517
# residual_sugar         -0.534540
# chlorides               0.940986
# free_sulfur_dioxide    -0.762016
# total_sulfur_dioxide   -1.340094
# density                 1.111614
# pH                      0.444682
# sulphates               0.125880
# alcohol                -0.831551
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.398674
# volatile_acidity        1.712513
# citric_acid            -1.895274
# residual_sugar         -0.355516
# chlorides               0.805916
# free_sulfur_dioxide    -0.335455
# total_sulfur_dioxide   -1.256374
# density                 1.039024
# pH                      0.738983
# sulphates              -0.001319
# alcohol                -0.831551
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.142462
# volatile_acidity       -0.909070
# citric_acid            -0.059409
# residual_sugar          1.903560
# chlorides              -0.314951
# free_sulfur_dioxide     0.477463
# total_sulfur_dioxide    1.366824
# density                 1.301698
# pH                     -0.737004
# sulphates              -0.210128
# alcohol                -1.083079
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.142462
# volatile_acidity       -0.909070
# citric_acid            -0.059409
# residual_sugar          1.903560
# chlorides              -0.314951
# free_sulfur_dioxide     0.477463
# total_sulfur_dioxide    1.366824
# density                 1.301698
# pH                     -0.737004
# sulphates              -0.210128
# alcohol                -1.083079
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.142462
# volatile_acidity       -0.909070
# citric_acid            -0.059409
# residual_sugar          1.903560
# chlorides              -0.314951
# free_sulfur_dioxide     0.477463
# total_sulfur_dioxide    1.366824
# density                 1.301698
# pH                     -0.737004
# sulphates              -0.210128
# alcohol                -1.083079
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.451001
# volatile_acidity        1.399046
# citric_acid            -1.573332
# residual_sugar         -0.660648
# chlorides               0.255930
# free_sulfur_dioxide     0.195763
# total_sulfur_dioxide   -1.251632
# density                -0.175622
# pH                      1.501980
# sulphates               1.402712
# alcohol                 1.851411
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.474615
# volatile_acidity        1.095347
# citric_acid            -1.642146
# residual_sugar         -0.639630
# chlorides               0.398650
# free_sulfur_dioxide    -0.987375
# total_sulfur_dioxide   -1.587785
# density                -0.372376
# pH                      1.128816
# sulphates               1.268308
# alcohol                 1.683725
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.032656
# volatile_acidity        1.240356
# citric_acid            -1.609289
# residual_sugar         -0.649666
# chlorides               0.330504
# free_sulfur_dioxide    -0.422455
# total_sulfur_dioxide   -1.427280
# density                -0.278431
# pH                      1.306993
# sulphates               1.332483
# alcohol                 1.763791
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.065328
# volatile_acidity       -0.058711
# citric_acid            -0.678741
# residual_sugar         -0.849811
# chlorides              -0.429127
# free_sulfur_dioxide     0.533803
# total_sulfur_dioxide    1.083748
# density                -0.609147
# pH                     -0.488228
# sulphates              -0.344531
# alcohol                -0.496181
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.628884
# volatile_acidity        0.062769
# citric_acid            -0.747556
# residual_sugar         -0.702685
# chlorides              -0.143687
# free_sulfur_dioxide     0.871842
# total_sulfur_dioxide    0.977594
# density                -0.499099
# pH                     -0.363840
# sulphates              -0.210128
# alcohol                -0.831551
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.524360
# volatile_acidity        0.044478
# citric_acid            -0.737195
# residual_sugar         -0.724837
# chlorides              -0.186664
# free_sulfur_dioxide     0.820945
# total_sulfur_dioxide    0.993577
# density                -0.515668
# pH                     -0.382569
# sulphates              -0.230365
# alcohol                -0.781056
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.373866
# volatile_acidity        0.305728
# citric_acid             0.147035
# residual_sugar          0.957745
# chlorides              -0.000967
# free_sulfur_dioxide     0.252103
# total_sulfur_dioxide    1.101440
# density                 0.901521
# pH                      0.258100
# sulphates               0.461889
# alcohol                -0.244653
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.682405
# volatile_acidity       -0.058711
# citric_acid             0.284664
# residual_sugar          0.411275
# chlorides              -0.543303
# free_sulfur_dioxide     0.308443
# total_sulfur_dioxide    0.712210
# density                 0.407969
# pH                     -0.177258
# sulphates               0.058679
# alcohol                 0.090717
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.482156
# volatile_acidity        0.177818
# citric_acid             0.195340
# residual_sugar          0.765947
# chlorides              -0.191314
# free_sulfur_dioxide     0.271877
# total_sulfur_dioxide    0.964829
# density                 0.728296
# pH                      0.105299
# sulphates               0.320371
# alcohol                -0.126946
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.605270
# volatile_acidity       -0.666110
# citric_acid             0.353479
# residual_sugar          0.873673
# chlorides              -0.058055
# free_sulfur_dioxide    -0.423976
# total_sulfur_dioxide    0.765287
# density                 1.084935
# pH                      0.631264
# sulphates              -0.411733
# alcohol                -0.580023
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.990944
# volatile_acidity       -0.605370
# citric_acid             0.491108
# residual_sugar          1.041818
# chlorides              -0.343495
# free_sulfur_dioxide    -0.592996
# total_sulfur_dioxide    0.464518
# density                 0.901521
# pH                     -0.115064
# sulphates              -0.008523
# alcohol                -0.412338
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.813353
# volatile_acidity       -0.633339
# citric_acid             0.427734
# residual_sugar          0.964392
# chlorides              -0.212058
# free_sulfur_dioxide    -0.515167
# total_sulfur_dioxide    0.603013
# density                 0.985978
# pH                      0.228598
# sulphates              -0.194189
# alcohol                -0.489552
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           1.530886
# volatile_acidity        1.520526
# citric_acid            -0.541112
# residual_sugar         -0.450467
# chlorides               1.283515
# free_sulfur_dioxide    -0.592996
# total_sulfur_dioxide   -1.216248
# density                 1.368394
# pH                      0.258100
# sulphates               0.932300
# alcohol                -0.747709
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           1.530886
# volatile_acidity        1.763485
# citric_acid            -0.747556
# residual_sugar         -0.576576
# chlorides               1.169338
# free_sulfur_dioxide    -0.085936
# total_sulfur_dioxide   -0.897787
# density                 1.368394
# pH                      0.382488
# sulphates               0.327485
# alcohol                -0.747709
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           1.530886
# volatile_acidity        1.674941
# citric_acid            -0.672320
# residual_sugar         -0.530617
# chlorides               1.210949
# free_sulfur_dioxide    -0.270728
# total_sulfur_dioxide   -1.013846
# density                 1.368394
# pH                      0.337156
# sulphates               0.547903
# alcohol                -0.747709
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.860289
# volatile_acidity       -0.362411
# citric_acid            -0.678741
# residual_sugar         -0.765739
# chlorides              -0.628935
# free_sulfur_dioxide     0.083083
# total_sulfur_dioxide    0.004519
# density                -1.632934
# pH                      0.880040
# sulphates              -0.613338
# alcohol                 1.767568
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.860289
# volatile_acidity       -0.119451
# citric_acid            -0.541112
# residual_sugar         -0.828793
# chlorides              -0.571847
# free_sulfur_dioxide     0.421123
# total_sulfur_dioxide    0.146057
# density                -1.632934
# pH                      0.444682
# sulphates              -0.747741
# alcohol                 1.599883
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.860289
# volatile_acidity       -0.302426
# citric_acid            -0.644761
# residual_sugar         -0.781307
# chlorides              -0.614840
# free_sulfur_dioxide     0.166543
# total_sulfur_dioxide    0.039464
# density                -1.632934
# pH                      0.772553
# sulphates              -0.646521
# alcohol                 1.726168
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.065328
# volatile_acidity        0.366468
# citric_acid            -0.541112
# residual_sugar          0.264148
# chlorides               0.056121
# free_sulfur_dioxide     0.590143
# total_sulfur_dioxide    0.889133
# density                 0.101167
# pH                     -0.115064
# sulphates              -0.814943
# alcohol                -0.496181
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.065328
# volatile_acidity       -0.240931
# citric_acid            -0.678741
# residual_sugar          0.201094
# chlorides              -0.000967
# free_sulfur_dioxide     0.759163
# total_sulfur_dioxide    0.924517
# density                 0.001123
# pH                     -0.550422
# sulphates              -1.218153
# alcohol                -0.328496
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.065328
# volatile_acidity        0.334099
# citric_acid            -0.548446
# residual_sugar          0.260788
# chlorides               0.053079
# free_sulfur_dioxide     0.599150
# total_sulfur_dioxide    0.891018
# density                 0.095835
# pH                     -0.138265
# sulphates              -0.836430
# alcohol                -0.487245
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.088942
# volatile_acidity        0.184248
# citric_acid            -0.128224
# residual_sugar          0.159058
# chlorides              -0.457671
# free_sulfur_dioxide     1.040862
# total_sulfur_dioxide    0.411441
# density                -1.496206
# pH                     -0.301646
# sulphates              -1.755766
# alcohol                 2.605994
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.243211
# volatile_acidity        0.123508
# citric_acid             0.147035
# residual_sugar         -0.261304
# chlorides              -1.085640
# free_sulfur_dioxide     1.491582
# total_sulfur_dioxide    0.057596
# density                -1.632934
# pH                      0.382488
# sulphates              -1.150951
# alcohol                 1.851411
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.098306
# volatile_acidity        0.180561
# citric_acid            -0.111516
# residual_sugar          0.133542
# chlorides              -0.495789
# free_sulfur_dioxide     1.068221
# total_sulfur_dioxide    0.389963
# density                -1.504506
# pH                     -0.260119
# sulphates              -1.719054
# alcohol                 2.560190
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.320346
# volatile_acidity       -0.423150
# citric_acid             0.353479
# residual_sugar          0.579420
# chlorides              -0.029511
# free_sulfur_dioxide     1.209882
# total_sulfur_dioxide    1.349132
# density                 0.387960
# pH                     -0.674810
# sulphates              -0.075725
# alcohol                -0.831551
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.243211
# volatile_acidity       -0.301671
# citric_acid             0.628737
# residual_sugar          0.495347
# chlorides              -0.286407
# free_sulfur_dioxide     1.209882
# total_sulfur_dioxide    0.977594
# density                 0.224555
# pH                     -0.612616
# sulphates              -0.142926
# alcohol                -0.747709
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.286290
# volatile_acidity       -0.369515
# citric_acid             0.475009
# residual_sugar          0.542300
# chlorides              -0.142934
# free_sulfur_dioxide     1.209882
# total_sulfur_dioxide    1.185093
# density                 0.315815
# pH                     -0.647351
# sulphates              -0.105395
# alcohol                -0.794534
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.166076
# volatile_acidity       -0.301671
# citric_acid             0.078220
# residual_sugar         -0.954902
# chlorides              -0.429127
# free_sulfur_dioxide    -0.592996
# total_sulfur_dioxide    0.022211
# density                -1.406167
# pH                     -0.052870
# sulphates              -0.210128
# alcohol                 0.761457
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.166076
# volatile_acidity       -0.301671
# citric_acid             0.078220
# residual_sugar         -0.954902
# chlorides              -0.429127
# free_sulfur_dioxide    -0.592996
# total_sulfur_dioxide    0.022211
# density                -1.406167
# pH                     -0.052870
# sulphates              -0.210128
# alcohol                 0.761457
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.166076
# volatile_acidity       -0.301671
# citric_acid             0.078220
# residual_sugar         -0.954902
# chlorides              -0.429127
# free_sulfur_dioxide    -0.592996
# total_sulfur_dioxide    0.022211
# density                -1.406167
# pH                     -0.052870
# sulphates              -0.210128
# alcohol                 0.761457
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.219597
# volatile_acidity        1.034607
# citric_acid            -2.055034
# residual_sugar         -0.786757
# chlorides               0.798266
# free_sulfur_dioxide    -0.987375
# total_sulfur_dioxide   -1.499324
# density                 0.227890
# pH                      0.880040
# sulphates               0.058679
# alcohol                 0.006874
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.296732
# volatile_acidity        1.216826
# citric_acid            -2.055034
# residual_sugar         -0.786757
# chlorides               0.826810
# free_sulfur_dioxide    -0.762016
# total_sulfur_dioxide   -1.499324
# density                 0.397965
# pH                      0.942234
# sulphates              -0.142926
# alcohol                -0.076968
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.232210
# volatile_acidity        1.064404
# citric_acid            -2.055034
# residual_sugar         -0.786757
# chlorides               0.802934
# free_sulfur_dioxide    -0.950523
# total_sulfur_dioxide   -1.499324
# density                 0.255701
# pH                      0.890210
# sulphates               0.025711
# alcohol                -0.006836
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.166076
# volatile_acidity       -0.605370
# citric_acid             0.215849
# residual_sugar         -0.933884
# chlorides              -0.686023
# free_sulfur_dioxide     0.646483
# total_sulfur_dioxide   -0.207788
# density                -1.606255
# pH                     -0.363840
# sulphates              -1.083749
# alcohol                 1.012985
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.551750
# volatile_acidity       -0.666110
# ...
# total_sulfur_dioxide   -0.101635
# density                -1.019329
# pH                     -0.861392
# sulphates               0.394687
# alcohol                 1.683725
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.166076
# volatile_acidity       -0.362411
# citric_acid             0.009405
# residual_sugar          0.484838
# chlorides              -0.686023
# free_sulfur_dioxide    -0.029596
# total_sulfur_dioxide   -0.030865
# density                -1.039338
# pH                     -0.612616
# sulphates               0.730695
# alcohol                 1.935253
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.194376
# volatile_acidity       -0.362411
# citric_acid             0.148265
# residual_sugar          0.479055
# chlorides              -0.696496
# free_sulfur_dioxide    -0.029596
# total_sulfur_dioxide   -0.043848
# density                -1.035667
# pH                     -0.658253
# sulphates               0.669056
# alcohol                 1.889112
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.065328
# volatile_acidity       -0.544630
# citric_acid            -0.334668
# residual_sugar         -0.345377
# chlorides              -0.257863
# free_sulfur_dioxide    -0.818356
# total_sulfur_dioxide   -0.650095
# density                -0.989316
# pH                     -0.923586
# sulphates              -0.478935
# alcohol                 0.677615
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.142462
# volatile_acidity       -0.483890
# citric_acid            -0.197039
# residual_sugar         -0.366395
# chlorides              -0.229319
# free_sulfur_dioxide    -0.931035
# total_sulfur_dioxide   -0.756249
# density                -1.066016
# pH                     -0.985780
# sulphates              -0.546136
# alcohol                 0.761457
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.079604
# volatile_acidity       -0.533388
# citric_acid            -0.309195
# residual_sugar         -0.349267
# chlorides              -0.252580
# free_sulfur_dioxide    -0.839211
# total_sulfur_dioxide   -0.669742
# density                -1.003511
# pH                     -0.935097
# sulphates              -0.491372
# alcohol                 0.693133
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -1.091693
# volatile_acidity       -0.666110
# citric_acid            -0.059409
# residual_sugar         -0.408431
# chlorides              -0.343495
# free_sulfur_dioxide     0.252103
# total_sulfur_dioxide    0.747594
# density                -1.572907
# pH                     -0.177258
# sulphates              -1.083749
# alcohol                 1.348355
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.937423
# volatile_acidity       -0.483890
# citric_acid            -0.197039
# residual_sugar         -0.492504
# chlorides              -0.429127
# free_sulfur_dioxide     0.364783
# total_sulfur_dioxide    0.499903
# density                -1.752987
# pH                      0.009324
# sulphates              -0.949346
# alcohol                 1.935253
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.997085
# volatile_acidity       -0.554361
# citric_acid            -0.143812
# residual_sugar         -0.459990
# chlorides              -0.396010
# free_sulfur_dioxide     0.321206
# total_sulfur_dioxide    0.595694
# density                -1.683343
# pH                     -0.062834
# sulphates              -1.001325
# alcohol                 1.708278
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.860289
# volatile_acidity        0.002029
# citric_acid            -0.747556
# residual_sugar         -0.093160
# chlorides              -0.400583
# free_sulfur_dioxide    -0.762016
# total_sulfur_dioxide    0.305288
# density                -0.322354
# pH                     -1.234556
# sulphates              -0.008523
# alcohol                -0.915394
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.860289
# volatile_acidity        0.002029
# citric_acid            -0.747556
# residual_sugar         -0.093160
# chlorides              -0.400583
# free_sulfur_dioxide    -0.762016
# total_sulfur_dioxide    0.305288
# density                -0.322354
# pH                     -1.234556
# sulphates              -0.008523
# alcohol                -0.915394
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.860289
# volatile_acidity        0.002029
# citric_acid            -0.747556
# residual_sugar         -0.093160
# chlorides              -0.400583
# free_sulfur_dioxide    -0.762016
# total_sulfur_dioxide    0.305288
# density                -0.322354
# pH                     -1.234556
# sulphates              -0.008523
# alcohol                -0.915394
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.628884
# volatile_acidity        0.244988
# citric_acid            -0.885185
# residual_sugar         -0.198250
# chlorides              -0.514759
# free_sulfur_dioxide     0.308443
# total_sulfur_dioxide    0.057596
# density                -1.062681
# pH                     -0.923586
# sulphates              -0.747741
# alcohol                 0.593772
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.783154
# volatile_acidity        0.123508
# citric_acid            -0.678741
# residual_sugar         -0.040614
# chlorides              -0.514759
# free_sulfur_dioxide     0.759163
# total_sulfur_dioxide    0.517595
# density                -0.952633
# pH                      0.009324
# sulphates              -0.882144
# alcohol                 0.593772
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.731108
# volatile_acidity        0.164492
# citric_acid            -0.748390
# residual_sugar         -0.093796
# chlorides              -0.514759
# free_sulfur_dioxide     0.607103
# total_sulfur_dioxide    0.362404
# density                -0.989760
# pH                     -0.305414
# sulphates              -0.836801
# alcohol                 0.593772
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           1.299482
# volatile_acidity        0.002029
# citric_acid             0.009405
# residual_sugar         -0.870829
# chlorides              -0.429127
# free_sulfur_dioxide    -1.043715
# total_sulfur_dioxide    1.278363
# density                 0.201211
# pH                     -0.301646
# sulphates              -0.277330
# alcohol                -0.831551
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           1.376617
# volatile_acidity        0.548688
# citric_acid            -0.128224
# residual_sugar         -0.828793
# chlorides              -0.172231
# free_sulfur_dioxide    -1.325415
# total_sulfur_dioxide    1.048363
# density                 0.134515
# pH                     -0.674810
# sulphates              -0.546136
# alcohol                -0.663866
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           1.324091
# volatile_acidity        0.176432
# citric_acid            -0.034503
# residual_sugar         -0.857418
# chlorides              -0.347168
# free_sulfur_dioxide    -1.133587
# total_sulfur_dioxide    1.204985
# density                 0.179933
# pH                     -0.420698
# sulphates              -0.363088
# alcohol                -0.778054
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.551750
# volatile_acidity        0.730907
# citric_acid             0.628737
# residual_sugar          2.386976
# chlorides               0.798266
# free_sulfur_dioxide     1.604262
# total_sulfur_dioxide    1.879900
# density                 1.535134
# pH                     -0.239452
# sulphates               0.327485
# alcohol                -1.250764
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.397480
# volatile_acidity       -0.240931
# citric_acid             0.835181
# residual_sugar          2.796829
# chlorides               0.027577
# free_sulfur_dioxide     1.942301
# total_sulfur_dioxide    1.915284
# density                 1.621839
# pH                     -0.674810
# sulphates              -0.008523
# alcohol                -1.166921
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.441437
# volatile_acidity        0.035978
# citric_acid             0.776359
# residual_sugar          2.680049
# chlorides               0.247172
# free_sulfur_dioxide     1.845983
# total_sulfur_dioxide    1.905202
# density                 1.597134
# pH                     -0.550762
# sulphates               0.087217
# alcohol                -1.190811
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.860289
# volatile_acidity       -0.483890
# citric_acid            -0.265853
# residual_sugar         -0.786757
# chlorides              -0.372039
# free_sulfur_dioxide    -0.367636
# total_sulfur_dioxide   -0.313942
# density                -1.839692
# pH                     -0.488228
# sulphates              -0.613338
# alcohol                 1.683725
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.860289
# volatile_acidity       -0.362411
# citric_acid            -0.403482
# residual_sugar         -0.828793
# chlorides              -0.743111
# free_sulfur_dioxide    -0.311296
# total_sulfur_dioxide   -0.260865
# density                -1.919727
# pH                     -1.172362
# sulphates              -0.814943
# alcohol                 1.348355
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.860289
# volatile_acidity       -0.446182
# citric_acid            -0.308575
# residual_sugar         -0.799805
# chlorides              -0.487223
# free_sulfur_dioxide    -0.350148
# total_sulfur_dioxide   -0.297466
# density                -1.864535
# pH                     -0.700590
# sulphates              -0.675918
# alcohol                 1.579623
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity           0.373866
# volatile_acidity       -0.666110
# citric_acid            -0.059409
# residual_sugar          1.104872
# chlorides              -0.514759
# free_sulfur_dioxide     1.604262
# total_sulfur_dioxide    1.242978
# density                 0.734780
# pH                     -0.612616
# sulphates               0.125880
# alcohol                -0.831551
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.219597
# volatile_acidity       -0.666110
# citric_acid             0.009405
# residual_sugar          0.789601
# chlorides              -0.514759
# free_sulfur_dioxide     1.322562
# total_sulfur_dioxide    1.331439
# density                 0.634736
# pH                     -1.110168
# sulphates               0.193082
# alcohol                -0.663866
# dtype: float64
#
# The synthetic data is:
# fixed_acidity           0.246157
# volatile_acidity       -0.666110
# citric_acid            -0.002442
# residual_sugar          0.843879
# chlorides              -0.514759
# free_sulfur_dioxide     1.371060
# total_sulfur_dioxide    1.316210
# density                 0.651960
# pH                     -1.024508
# sulphates               0.181512
# alcohol                -0.692735
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.011807
# volatile_acidity       -0.787590
# citric_acid             0.284664
# residual_sugar          2.155777
# chlorides              -0.314951
# free_sulfur_dioxide     2.111321
# total_sulfur_dioxide    1.189901
# density                 1.508456
# pH                      0.195906
# sulphates               1.537115
# alcohol                -0.915394
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.065328
# volatile_acidity       -0.726850
# citric_acid             0.353479
# residual_sugar          2.113741
# chlorides              -0.229319
# free_sulfur_dioxide     2.224001
# total_sulfur_dioxide    1.543747
# density                 1.431755
# pH                      0.195906
# sulphates               1.604317
# alcohol                -0.915394
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.009481
# volatile_acidity       -0.785758
# citric_acid             0.286739
# residual_sugar          2.154510
# chlorides              -0.312369
# free_sulfur_dioxide     2.114718
# total_sulfur_dioxide    1.200569
# density                 1.506143
# pH                      0.195906
# sulphates               1.539141
# alcohol                -0.915394
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.397480
# volatile_acidity       -0.666110
# citric_acid             0.078220
# residual_sugar          0.558401
# chlorides              -0.229319
# free_sulfur_dioxide     0.815503
# total_sulfur_dioxide    1.066055
# density                 0.007792
# pH                     -0.674810
# sulphates              -0.075725
# alcohol                -0.328496
# dtype: float64
#
# The label was:
# quality    1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity          -0.011807
# volatile_acidity       -0.180191
# citric_acid             0.215849
# residual_sugar          0.369239
# chlorides              -0.286407
# free_sulfur_dioxide     0.815503
# total_sulfur_dioxide    1.101440
# density                 0.267907
# pH                     -0.488228
# sulphates              -0.008523
# alcohol                -0.663866
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.200337
# volatile_acidity       -0.417724
# citric_acid             0.148572
# residual_sugar          0.461708
# chlorides              -0.258500
# free_sulfur_dioxide     0.815503
# total_sulfur_dioxide    1.084143
# density                 0.140754
# pH                     -0.579436
# sulphates              -0.041373
# alcohol                -0.499926
# dtype: float64
#
# Another data
#
# The sample was:
# fixed_acidity          -0.011807
# volatile_acidity       -0.848330
# citric_acid            -0.678741
# residual_sugar         -0.807775
# chlorides              -0.343495
# free_sulfur_dioxide    -0.762016
# total_sulfur_dioxide   -0.260865
# density                 0.004457
# pH                      0.942234
# sulphates              -0.008523
# alcohol                -0.412338
# dtype: float64
#
# The label was:
# quality   -1
# dtype: int64
#
# The closest neighbor was:
# fixed_acidity           0.065328
# volatile_acidity       -0.544630
# citric_acid            -0.265853
# residual_sugar         -0.828793
# chlorides              -0.372039
# free_sulfur_dioxide    -0.649336
# total_sulfur_dioxide   -0.048558
# density                -0.439072
# pH                      1.004428
# sulphates               0.193082
# alcohol                -0.328496
# dtype: float64
#
# The synthetic data is:
# fixed_acidity          -0.011655
# volatile_acidity       -0.847731
# citric_acid            -0.677928
# residual_sugar         -0.807816
# chlorides              -0.343551
# free_sulfur_dioxide    -0.761794
# total_sulfur_dioxide   -0.260447
# density                 0.003584
# pH                      0.942356
# sulphates              -0.008126
# alcohol                -0.412173
# dtype: float64
#
# Another data
#
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0       0.100985         -0.166209    -0.032922       -0.823955  -0.571901
# 1      -0.512080         -0.574132     0.535673       -0.733813  -0.466914
# 2       0.557183         -0.906818     1.315609        0.231585  -0.939745
# 3       0.199036          1.755390    -1.090696       -0.757889   0.482004
# 4      -0.628884         -0.137513    -0.644233        0.792664  -0.411984
#
#    free_sulfur_dioxide  total_sulfur_dioxide   density        pH  sulphates  \
# 0             0.251996              0.697289 -1.067035 -1.593404  -0.685738
# 1             0.451709             -0.355731 -1.161615  0.817846  -0.958305
# 2            -0.517528             -0.495560 -0.531211 -0.699384  -1.019039
# 3            -0.095694              0.473710  0.209041  0.122941  -0.454746
# 4             0.173095             -0.053974 -0.552553 -1.421138  -1.345895
#
#     alcohol
# 0  0.084231
# 1  0.775032
# 2  1.209136
# 3 -0.572195
# 4  0.487686
#    quality
# 0        1
# 1        1
# 2        1
# 3       -1
# 4        1

# %%
df = X.copy()

df['quality'] = y

df_good = df[df['quality'] == 1]

df_bad = df[df['quality'] == -1]

n_bad = len(df_bad)

df_good_undersampled = df_good.sample(n=n_bad, random_state=42)

df_undersampled = pd.concat([df_good_undersampled, df_bad])

y_undersampled = df_undersampled['quality']

X_undersampled = df_undersampled.drop('quality', axis=1)
print(f"Undersampling completato! Nuova dimensione X: {len(X_undersampled)}, nuova dimensione y: {len(y_undersampled)}")
# Out:
# Undersampling completato! Nuova dimensione X: 4768, nuova dimensione y: 4768

# %%
X_array = np.array(X_undersampled)

Y_array = np.array(y_undersampled)

index = np.arange(len(X_array))

np.random.shuffle(index)

X_array = X_array[index]

Y_array = Y_array[index]
